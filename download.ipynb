# %%
import os
import time
from datetime import datetime, timedelta

# %%
os.add_dll_directory('C:\\Program Files\\IBM\\SQLLIB\\BIN')
# conectar a la base de datos IBM Db2
import ibm_db

# %%
from queries import get_academic_history, get_socioeconomico, tasa_reprobacion, dificultad_materia
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def format_time(seconds):
    """Convierte segundos a formato HH:MM:SS"""
    return str(timedelta(seconds=int(seconds)))

def print_progress_bar(current, total, bar_length=30):
    """Imprime una barra de progreso"""
    percent = float(current) * 100 / total
    filled_length = int(bar_length * current // total)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    return f'[{bar}] {percent:.1f}% ({current}/{total})'

# %%
print("="*80)
print("INICIO DE DESCARGA DE DATOS ACADÉMICOS")
print("="*80)
print(f"Fecha y hora de inicio: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ================================================================================
# INICIO DE DESCARGA DE DATOS ACADÉMICOS
# ================================================================================
# Fecha y hora de inicio: 2025-09-29 09:46:43

# %%
# Tiempo de inicio total
start_time_total = time.time()

print("\n📡 Conectando con la base de datos...")
start_time_conn = time.time()
# Out:
# 📡 Conectando con la base de datos...

# %%
conn_str = (
    'DATABASE=' + os.getenv('DATABASE') + 
    ';HOSTNAME=' + os.getenv('HOSTNAME') + 
    ';PORT=' + os.getenv('PORT') + 
    ';PROTOCOL=TCPIP;UID=' + os.getenv('USERNAME_DB') + 
    ';PWD=' + os.getenv('PASSWORD_DB') + ';'
)

print(repr(conn_str))
conn = ibm_db.connect(conn_str, '', '')
# Out:
# 'DATABASE=SAAC;HOSTNAME=192.168.254.53;PORT=50000;PROTOCOL=TCPIP;UID=espol;PWD=espol123;'

# %%
end_time_conn = time.time()
connection_time = end_time_conn - start_time_conn

if conn:
    print(f"✅ Conexión exitosa - Tiempo: {connection_time:.2f} segundos")
else:
    print("❌ Error al conectar")
    exit(1)
# Out:
# ✅ Conexión exitosa - Tiempo: 107.02 segundos

# %%
# Cargar datos de materias
print("\n📁 Cargando lista de materias...")
start_time_load = time.time()
df_materias = pd.read_csv("./data/materias/tasa_reprobacion_dificultad.csv")
end_time_load = time.time()
load_time = end_time_load - start_time_load

print(f"✅ Materias cargadas - Tiempo: {load_time:.2f} segundos")
print(f"📊 Total de materias en archivo: {len(df_materias)}")
# Out:
# 📁 Cargando lista de materias...
# ✅ Materias cargadas - Tiempo: 0.01 segundos
# 📊 Total de materias en archivo: 741

# %%
# Filtrar materias a procesar
list_not_grades = ["PORTAFOLIO"]
materias_to_process = []

for i in df_materias.iterrows():
    if i[1]["MATERIA_x"] in list_not_grades or "MATERIA INTEGRADORA" in i[1]["MATERIA_x"]:
        continue
    materias_to_process.append(i[1])

# %%
total_materias = len(materias_to_process)
print(f"🎯 Materias a procesar: {total_materias}")

# Parámetros de configuración
year = "2024"
semester = "2S"
print(f"📅 Período: {year} - {semester}")
# Out:
# 🎯 Materias a procesar: 706
# 📅 Período: 2024 - 2S

# %%
print("\n" + "="*80)
print("INICIANDO PROCESAMIENTO DE MATERIAS")
print("="*80)

# Variables para estadísticas
total_students_processed = 0
failed_materias = []
processing_times = []
# Out:
# ================================================================================
# INICIANDO PROCESAMIENTO DE MATERIAS
# ================================================================================

# %%
# Procesar cada materia
for counter, materia_data in enumerate(materias_to_process, 1):
    print(f"\n{'='*60}")
    print(f"PROCESANDO MATERIA {counter}/{total_materias}")
    print(f"{'='*60}")
    
    cod_materia = materia_data["CODIGOMATERIA"].strip()
    materia_name = materia_data["MATERIA_x"]
    
    print(f"📚 Código: {cod_materia}")
    print(f"📖 Nombre: {materia_name}")
    print(f"⏱️  {print_progress_bar(counter-1, total_materias)}")
    
    # Tiempo de inicio para esta materia
    start_time_materia = time.time()
    
    try:
        # Query 1: Historial académico
        print(f"\n🔍 Ejecutando query de historial académico...")
        start_time_query1 = time.time()
        
        query = get_academic_history(cod_materia, year, semester)
        stmt_select = ibm_db.exec_immediate(conn, query)
        
        data_list = []
        result = ibm_db.fetch_assoc(stmt_select)
        while result:
            result["COD_MATERIA_ACAD_MO"] = result["COD_MATERIA_ACAD_MO"].strip()
            data_list.append(result)
            result = ibm_db.fetch_assoc(stmt_select)
        
        df = pd.DataFrame(data_list)
        end_time_query1 = time.time()
        query1_time = end_time_query1 - start_time_query1
        
        num_students = len(df)
        print(f"✅ Query 1 completada - Estudiantes encontrados: {num_students} - Tiempo: {query1_time:.2f}s")
        
        if num_students == 0:
            print(f"⚠️  No hay estudiantes para esta materia, saltando...")
            continue
        
        # Query 2: Datos socioeconómicos
        print(f"🔍 Ejecutando query socioeconómico...")
        start_time_query2 = time.time()
        
        query = get_socioeconomico(df["COD_ESTUDIANTE"].to_list())
        stmt_select = ibm_db.exec_immediate(conn, query)
        
        data_list = []
        result = ibm_db.fetch_assoc(stmt_select)
        while result:
            data_list.append(result)
            result = ibm_db.fetch_assoc(stmt_select)
        
        df_socio = pd.DataFrame(data_list)
        end_time_query2 = time.time()
        query2_time = end_time_query2 - start_time_query2
        
        socio_records = len(df_socio)
        print(f"✅ Query 2 completada - Registros socioeconómicos: {socio_records} - Tiempo: {query2_time:.2f}s")
        
        # Merge y guardado
        print(f"🔗 Realizando merge y guardando archivo...")
        start_time_merge = time.time()
        
        df["COD_ESTUDIANTE"] = df["COD_ESTUDIANTE"].astype(str).str.strip()
        df_socio["CODESTUDIANTE"] = df_socio["CODESTUDIANTE"].astype(str).str.strip()
        
        df_merge = pd.merge(df, df_socio, left_on='COD_ESTUDIANTE', right_on="CODESTUDIANTE", how='left')
        
        filename = f"./data/materias/{cod_materia}_{year}_{semester}.csv"
        df_merge.to_csv(filename, index=False)
        
        end_time_merge = time.time()
        merge_time = end_time_merge - start_time_merge
        
        # Tiempo total para esta materia
        end_time_materia = time.time()
        materia_time = end_time_materia - start_time_materia
        processing_times.append(materia_time)
        
        print(f"✅ Archivo guardado: {filename}")
        print(f"💾 Merge y guardado - Tiempo: {merge_time:.2f}s")
        print(f"📊 Registros finales: {len(df_merge)}")
        
        # Estadísticas de la materia
        total_students_processed += num_students
        coverage = (socio_records / num_students * 100) if num_students > 0 else 0
        
        print(f"\n📈 RESUMEN MATERIA:")
        print(f"   • Estudiantes académicos: {num_students}")
        print(f"   • Registros socioeconómicos: {socio_records}")
        print(f"   • Cobertura socioeconómica: {coverage:.1f}%")
        print(f"   • Query 1: {query1_time:.2f}s")
        print(f"   • Query 2: {query2_time:.2f}s")
        print(f"   • Merge/Guardado: {merge_time:.2f}s")
        print(f"   • Tiempo total materia: {format_time(materia_time)}")
        
        # Estimación de tiempo restante
        if len(processing_times) >= 3:  # Solo después de procesar al menos 3 materias
            avg_time_per_materia = sum(processing_times) / len(processing_times)
            remaining_materias = total_materias - counter
            estimated_remaining_time = avg_time_per_materia * remaining_materias
            
            print(f"⏰ Tiempo promedio por materia: {format_time(avg_time_per_materia)}")
            print(f"⏳ Tiempo estimado restante: {format_time(estimated_remaining_time)}")
            
            estimated_finish = datetime.now() + timedelta(seconds=estimated_remaining_time)
            print(f"🏁 Finalización estimada: {estimated_finish.strftime('%H:%M:%S')}")
        # break
    except Exception as e:
        print(f"❌ ERROR procesando {cod_materia}: {str(e)}")
        failed_materias.append({
            'codigo': cod_materia,
            'nombre': materia_name,
            'error': str(e)
        })
# Out:
# ============================================================
# PROCESANDO MATERIA 199/706
# ============================================================
# 📚 Código: ACUG1035
# 📖 Nombre: ACUICULTURA ORNAMENTAL
# ⏱️  [████████----------------------] 28.0% (198/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 2 - Tiempo: 12.55s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 2 - Tiempo: 8.22s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1035_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 2
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 2
#    • Registros socioeconómicos: 2
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.55s
#    • Query 2: 8.22s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:20
#
# ============================================================
# PROCESANDO MATERIA 200/706
# ============================================================
# 📚 Código: ACUG1036
# 📖 Nombre: ANÁLISIS DE DATOS ACUÍCOLAS
# ⏱️  [████████----------------------] 28.2% (199/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 5 - Tiempo: 12.38s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 5 - Tiempo: 7.53s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1036_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 5
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 5
#    • Registros socioeconómicos: 5
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.38s
#    • Query 2: 7.53s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:19
#
# ============================================================
# PROCESANDO MATERIA 201/706
# ============================================================
# 📚 Código: ACUG1039
# 📖 Nombre: CULTIVO DE ESPECIES NO TRADICIONALES
# ⏱️  [████████----------------------] 28.3% (200/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 3 - Tiempo: 12.52s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 3 - Tiempo: 8.12s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1039_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 3
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 3
#    • Registros socioeconómicos: 3
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.52s
#    • Query 2: 8.12s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:20
# ⏳ Tiempo estimado restante: 2:52:06
# 🏁 Finalización estimada: 12:41:38
#
# ============================================================
# PROCESANDO MATERIA 202/706
# ============================================================
# 📚 Código: ACUG1040
# 📖 Nombre: CULTIVO DE PLANCTON
# ⏱️  [████████----------------------] 28.5% (201/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 5 - Tiempo: 12.77s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 5 - Tiempo: 8.57s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1040_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 5
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 5
#    • Registros socioeconómicos: 5
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.77s
#    • Query 2: 8.57s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00

#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:19
# ⏳ Tiempo estimado restante: 2:42:47
# 🏁 Finalización estimada: 12:36:19
#
# ============================================================
# PROCESANDO MATERIA 215/706
# ============================================================
# 📚 Código: ACUG1054
# 📖 Nombre: INTRODUCCIÓN A LA ACUICULTURA
# ⏱️  [█████████---------------------] 30.3% (214/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 13 - Tiempo: 12.45s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 13 - Tiempo: 7.40s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1054_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 13
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 13
#    • Registros socioeconómicos: 13
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.45s
#    • Query 2: 7.40s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:19
# ⏰ Tiempo promedio por materia: 0:00:19
# ⏳ Tiempo estimado restante: 2:42:27
# 🏁 Finalización estimada: 12:36:19
#
# ============================================================
# PROCESANDO MATERIA 216/706
# ============================================================
# 📚 Código: ACUG1055
# 📖 Nombre: PROBLEMAS DE LA ACTUALIDAD ACUÍCOLA
# ⏱️  [█████████---------------------] 30.5% (215/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 9 - Tiempo: 12.70s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 8 - Tiempo: 7.60s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1055_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 9
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 9
#    • Registros socioeconómicos: 8
#    • Cobertura socioeconómica: 88.9%
#    • Query 1: 12.70s
#    • Query 2: 7.60s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:19
# ⏳ Tiempo estimado restante: 2:42:21
# 🏁 Finalización estimada: 12:36:33
#
# ============================================================
# PROCESANDO MATERIA 217/706
# ============================================================
# 📚 Código: ACUG1056
# 📖 Nombre: PATOLOGÍA ACUÍCOLA II
# ⏱️  [█████████---------------------] 30.6% (216/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 4 - Tiempo: 12.65s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 4 - Tiempo: 7.46s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1056_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 4
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 4
#    • Registros socioeconómicos: 4
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.65s
#    • Query 2: 7.46s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:19
# ⏳ Tiempo estimado restante: 2:42:07
# 🏁 Finalización estimada: 12:36:40
#
# ============================================================
# PROCESANDO MATERIA 218/706
# ============================================================
# 📚 Código: ACUG1057
# 📖 Nombre: PATOLOGÍA ACUÍCOLA I
# ⏱️  [█████████---------------------] 30.7% (217/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 4 - Tiempo: 12.42s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 4 - Tiempo: 7.38s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1057_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 4
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 4
#    • Registros socioeconómicos: 4
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.42s
#    • Query 2: 7.38s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:19
# ⏰ Tiempo promedio por materia: 0:00:19
# ⏳ Tiempo estimado restante: 2:41:46
# 🏁 Finalización estimada: 12:36:38
#
# ============================================================
# PROCESANDO MATERIA 219/706
# ============================================================
# 📚 Código: ACUG1059
# 📖 Nombre: BUENAS PRÁCTICAS EN ACUICULTURA
# ⏱️  [█████████---------------------] 30.9% (218/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 3 - Tiempo: 12.32s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 3 - Tiempo: 7.37s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ACUG1059_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 3
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 3
#    • Registros socioeconómicos: 3
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.32s
#    • Query 2: 7.37s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:19
# ⏰ Tiempo promedio por materia: 0:00:19
# ⏳ Tiempo estimado restante: 2:41:21
# 🏁 Finalización estimada: 12:36:33
#
# ============================================================
# PROCESANDO MATERIA 220/706
# ============================================================
# 📚 Código: ADMG1005
# 📖 Nombre: EMPRENDIMIENTO E INNOVACIÓN
# ⏱️  [█████████---------------------] 31.0% (219/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 549 - Tiempo: 42.26s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 539 - Tiempo: 11.25s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG1005_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.05s
# 📊 Registros finales: 549
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 549
#    • Registros socioeconómicos: 539
#    • Cobertura socioeconómica: 98.2%
#    • Query 1: 42.26s
#    • Query 2: 11.25s
#    • Merge/Guardado: 0.05s
#    • Tiempo total materia: 0:00:53
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:54:01
# 🏁 Finalización estimada: 12:50:06
#
# ============================================================
# PROCESANDO MATERIA 221/706
# ============================================================
# 📚 Código: ADMG1006
# 📖 Nombre: GESTIÓN DE PROYECTOS Y REGULACIÓN EN TELECOMUNICACIONES
# ⏱️  [█████████---------------------] 31.2% (220/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 15.04s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 10 - Tiempo: 7.74s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG1006_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 10
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Registros socioeconómicos: 10
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 15.04s
#    • Query 2: 7.74s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:54:08
# 🏁 Finalización estimada: 12:50:37
#
# ============================================================
# PROCESANDO MATERIA 222/706
# ============================================================
# 📚 Código: ADMG1007
# 📖 Nombre: ESTRATEGIAS DE GESTIÓN
# ⏱️  [█████████---------------------] 31.3% (221/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 18 - Tiempo: 12.50s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 17 - Tiempo: 7.38s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG1007_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 18
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 18
#    • Registros socioeconómicos: 17
#    • Cobertura socioeconómica: 94.4%
#    • Query 1: 12.50s
#    • Query 2: 7.38s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:19
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:53:12
# 🏁 Finalización estimada: 12:50:00
#
# ============================================================
# PROCESANDO MATERIA 223/706
# ============================================================
# 📚 Código: ADMG2022
# 📖 Nombre: ADMINISTRACIÓN DE OPERACIONES
# ⏱️  [█████████---------------------] 31.4% (222/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 52 - Tiempo: 14.10s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 50 - Tiempo: 7.68s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2022_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 52
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 52
#    • Registros socioeconómicos: 50
#    • Cobertura socioeconómica: 96.2%
#    • Query 1: 14.10s
#    • Query 2: 7.68s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:52:57
# 🏁 Finalización estimada: 12:50:07
#
# ============================================================
# PROCESANDO MATERIA 224/706
# ============================================================
# 📚 Código: ADMG2024
# 📖 Nombre: COMERCIO EXTERIOR
# ⏱️  [█████████---------------------] 31.6% (223/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 37 - Tiempo: 14.30s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 13 - Tiempo: 7.60s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2024_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 37
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 37
#    • Registros socioeconómicos: 13
#    • Cobertura socioeconómica: 35.1%
#    • Query 1: 14.30s
#    • Query 2: 7.60s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:52:44
# 🏁 Finalización estimada: 12:50:16
#
# ============================================================
# PROCESANDO MATERIA 225/706
# ============================================================
# 📚 Código: ADMG2025
# 📖 Nombre: COMPORTAMIENTO ORGANIZACIONAL
# ⏱️  [█████████---------------------] 31.7% (224/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 80 - Tiempo: 13.46s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 79 - Tiempo: 7.75s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2025_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.03s
# 📊 Registros finales: 80
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 80
#    • Registros socioeconómicos: 79
#    • Cobertura socioeconómica: 98.8%
#    • Query 1: 13.46s
#    • Query 2: 7.75s
#    • Merge/Guardado: 0.03s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:52:18
# 🏁 Finalización estimada: 12:50:11
#
# ============================================================
# PROCESANDO MATERIA 226/706
# ============================================================
# 📚 Código: ADMG2026
# 📖 Nombre: DESARROLLO ORGANIZACIONAL
# ⏱️  [█████████---------------------] 31.9% (225/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 44 - Tiempo: 13.84s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 44 - Tiempo: 7.66s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2026_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.03s
# 📊 Registros finales: 44
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 44
#    • Registros socioeconómicos: 44
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 13.84s
#    • Query 2: 7.66s
#    • Merge/Guardado: 0.03s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:51:57
# 🏁 Finalización estimada: 12:50:11
#
# ============================================================
# PROCESANDO MATERIA 227/706
# ============================================================
# 📚 Código: ADMG2028
# 📖 Nombre: ESTRATEGIAS CORPORATIVAS Y DE NEGOCIOS
# ⏱️  [█████████---------------------] 32.0% (226/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 39 - Tiempo: 15.24s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 16 - Tiempo: 7.88s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2028_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 39
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 39
#    • Registros socioeconómicos: 16
#    • Cobertura socioeconómica: 41.0%
#    • Query 1: 15.24s
#    • Query 2: 7.88s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:52:04
# 🏁 Finalización estimada: 12:50:41
#
# ============================================================
# PROCESANDO MATERIA 228/706
# ============================================================
# 📚 Código: ADMG2029
# 📖 Nombre: FUNDAMENTOS DE ADMINISTRACIÓN
# ⏱️  [█████████---------------------] 32.2% (227/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 173 - Tiempo: 15.08s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 164 - Tiempo: 8.47s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2029_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 174
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 173
#    • Registros socioeconómicos: 164
#    • Cobertura socioeconómica: 94.8%
#    • Query 1: 15.08s
#    • Query 2: 8.47s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:52:15
# 🏁 Finalización estimada: 12:51:17
#
# ============================================================
# PROCESANDO MATERIA 229/706
# ============================================================
# 📚 Código: ADMG2030
# 📖 Nombre: FUNDAMENTOS DE MARKETING
# ⏱️  [█████████---------------------] 32.3% (228/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 97 - Tiempo: 13.53s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 97 - Tiempo: 8.57s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2030_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 97
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 97
#    • Registros socioeconómicos: 97
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 13.53s
#    • Query 2: 8.57s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:52:02
# 🏁 Finalización estimada: 12:51:25
#
# ============================================================
# PROCESANDO MATERIA 230/706
# ============================================================
# 📚 Código: ADMG2032
# 📖 Nombre: GESTIÓN COMERCIAL
# ⏱️  [█████████---------------------] 32.4% (229/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 31 - Tiempo: 13.21s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 28 - Tiempo: 8.72s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2032_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 31
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 31
#    • Registros socioeconómicos: 28
#    • Cobertura socioeconómica: 90.3%
#    • Query 1: 13.21s
#    • Query 2: 8.72s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:51:45
# 🏁 Finalización estimada: 12:51:30
#
# ============================================================
# PROCESANDO MATERIA 231/706
# ============================================================
# 📚 Código: ADMG2033
# 📖 Nombre: GESTIÓN DE MARKETING
# ⏱️  [█████████---------------------] 32.6% (230/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 26 - Tiempo: 12.90s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 22 - Tiempo: 7.64s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2033_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 26
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 26
#    • Registros socioeconómicos: 22
#    • Cobertura socioeconómica: 84.6%
#    • Query 1: 12.90s
#    • Query 2: 7.64s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:51:07
# 🏁 Finalización estimada: 12:51:13
#
# ============================================================
# PROCESANDO MATERIA 232/706
# ============================================================
# 📚 Código: ADMG2034
# 📖 Nombre: GESTIÓN DE RECURSOS HUMANOS
# ⏱️  [█████████---------------------] 32.7% (231/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 46 - Tiempo: 12.70s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 44 - Tiempo: 7.53s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2034_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 46
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 46
#    • Registros socioeconómicos: 44
#    • Cobertura socioeconómica: 95.7%
#    • Query 1: 12.70s
#    • Query 2: 7.53s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:50:26
# 🏁 Finalización estimada: 12:50:52
#
# ============================================================
# PROCESANDO MATERIA 233/706
# ============================================================
# 📚 Código: ADMG2035
# 📖 Nombre: INVESTIGACIÓN DE MERCADOS
# ⏱️  [█████████---------------------] 32.9% (232/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 83 - Tiempo: 13.94s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 83 - Tiempo: 8.07s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2035_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 83
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 83
#    • Registros socioeconómicos: 83
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 13.94s
#    • Query 2: 8.07s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:50:10
# 🏁 Finalización estimada: 12:50:59
#
# ============================================================
# PROCESANDO MATERIA 234/706
# ============================================================
# 📚 Código: ADMG2036
# 📖 Nombre: PLANIFICACIÓN ESTRATÉGICA
# ⏱️  [█████████---------------------] 33.0% (233/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 40 - Tiempo: 12.69s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 13 - Tiempo: 7.47s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2036_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 40
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 40
#    • Registros socioeconómicos: 13
#    • Cobertura socioeconómica: 32.5%
#    • Query 1: 12.69s
#    • Query 2: 7.47s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:49:30
# 🏁 Finalización estimada: 12:50:38
#
# ============================================================
# PROCESANDO MATERIA 235/706
# ============================================================
# 📚 Código: ADMG2037
# 📖 Nombre: GESTIÓN DE PROYECTOS
# ⏱️  [█████████---------------------] 33.1% (234/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 51 - Tiempo: 12.81s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 27 - Tiempo: 7.76s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMG2037_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 51
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 51
#    • Registros socioeconómicos: 27
#    • Cobertura socioeconómica: 52.9%
#    • Query 1: 12.81s
#    • Query 2: 7.76s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:48:56
# 🏁 Finalización estimada: 12:50:25
#
# ============================================================
# PROCESANDO MATERIA 236/706
# ============================================================
# 📚 Código: ADMT3004
# 📖 Nombre: LIDERAZGO Y EMPRENDIMIENTO
# ⏱️  [█████████---------------------] 33.3% (235/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 20 - Tiempo: 12.59s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 1 - Tiempo: 8.72s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADMT3004_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.02s
# 📊 Registros finales: 20
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 20
#    • Registros socioeconómicos: 1
#    • Cobertura socioeconómica: 5.0%
#    • Query 1: 12.59s
#    • Query 2: 8.72s
#    • Merge/Guardado: 0.02s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:48:32
# 🏁 Finalización estimada: 12:50:22
#
# ============================================================
# PROCESANDO MATERIA 237/706
# ============================================================
# 📚 Código: ADMT3005
# 📖 Nombre: COMERCIO EXTERIOR
# ⏱️  [██████████--------------------] 33.4% (236/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 4.43s
# ⚠️  No hay estudiantes para esta materia, saltando...
#
# ============================================================
# PROCESANDO MATERIA 238/706
# ============================================================
# 📚 Código: ADSG1019
# 📖 Nombre: CONTAMINACIÓN AMBIENTAL
# ⏱️  [██████████--------------------] 33.6% (237/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 14 - Tiempo: 14.02s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 14 - Tiempo: 7.48s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1019_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 14
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 14
#    • Registros socioeconómicos: 14
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 14.02s
#    • Query 2: 7.48s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:47:49
# 🏁 Finalización estimada: 12:50:05
#
# ============================================================
# PROCESANDO MATERIA 239/706
# ============================================================
# 📚 Código: ADSG1020
# 📖 Nombre: ECOLOGÍA ACUÁTICA
# ⏱️  [██████████--------------------] 33.7% (238/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 15 - Tiempo: 12.79s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 15 - Tiempo: 7.46s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1020_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.00s
# 📊 Registros finales: 15
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 15
#    • Registros socioeconómicos: 15
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.79s
#    • Query 2: 7.46s
#    • Merge/Guardado: 0.00s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:47:12
# 🏁 Finalización estimada: 12:49:48
#
# ============================================================
# PROCESANDO MATERIA 240/706
# ============================================================
# 📚 Código: ADSG1021
# 📖 Nombre: ECOLOGÍA DE ECOSISTEMAS
# ⏱️  [██████████--------------------] 33.9% (239/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 14 - Tiempo: 14.84s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 14 - Tiempo: 10.75s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1021_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 14
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 14
#    • Registros socioeconómicos: 14
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 14.84s
#    • Query 2: 10.75s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:25
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:47:38
# 🏁 Finalización estimada: 12:50:41
#
# ============================================================
# PROCESANDO MATERIA 241/706
# ============================================================
# 📚 Código: ADSG1022
# 📖 Nombre: ECOLOGÍA GENERAL
# ⏱️  [██████████--------------------] 34.0% (240/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 19 - Tiempo: 14.19s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 19 - Tiempo: 7.36s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1022_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 19
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 19
#    • Registros socioeconómicos: 19
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 14.19s
#    • Query 2: 7.36s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:47:17
# 🏁 Finalización estimada: 12:50:40
#
# ============================================================
# PROCESANDO MATERIA 242/706
# ============================================================
# 📚 Código: ADSG1023
# 📖 Nombre: REMEDIACIÓN AMBIENTAL
# ⏱️  [██████████--------------------] 34.1% (241/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 13.14s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 8 - Tiempo: 7.52s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1023_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 10
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Registros socioeconómicos: 8
#    • Cobertura socioeconómica: 80.0%
#    • Query 1: 13.14s
#    • Query 2: 7.52s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:46:45
# 🏁 Finalización estimada: 12:50:29
#
# ============================================================
# PROCESANDO MATERIA 243/706
# ============================================================
# 📚 Código: ADSG1024
# 📖 Nombre: PRINCIPIOS DE ECOTOXICOLOGÍA
# ⏱️  [██████████--------------------] 34.3% (242/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 15 - Tiempo: 12.82s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 14 - Tiempo: 7.57s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1024_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.00s
# 📊 Registros finales: 15
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 15
#    • Registros socioeconómicos: 14
#    • Cobertura socioeconómica: 93.3%
#    • Query 1: 12.82s
#    • Query 2: 7.57s
#    • Merge/Guardado: 0.00s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:46:11
# 🏁 Finalización estimada: 12:50:15
#
# ============================================================
# PROCESANDO MATERIA 244/706
# ============================================================
# 📚 Código: ADSG1025
# 📖 Nombre: GESTIÓN DE CALIDAD, AMBIENTE Y SEGURIDAD EN LA INDUSTRIA
# ⏱️  [██████████--------------------] 34.4% (243/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 21 - Tiempo: 12.47s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 21 - Tiempo: 7.63s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1025_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 21
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 21
#    • Registros socioeconómicos: 21
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.47s
#    • Query 2: 7.63s
#    • Merge/Guardado: 0.01s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:45:34
# 🏁 Finalización estimada: 12:49:59
#
# ============================================================
# PROCESANDO MATERIA 245/706
# ============================================================
# 📚 Código: ADSG1026
# 📖 Nombre: CIENCIAS DE LA SOSTENIBILIDAD
# ⏱️  [██████████--------------------] 34.6% (244/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 535 - Tiempo: 28.69s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 522 - Tiempo: 11.35s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1026_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.05s
# 📊 Registros finales: 535
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 535
#    • Registros socioeconómicos: 522
#    • Cobertura socioeconómica: 97.6%
#    • Query 1: 28.69s
#    • Query 2: 11.35s
#    • Merge/Guardado: 0.05s
#    • Tiempo total materia: 0:00:40
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:48:23
# 🏁 Finalización estimada: 12:53:28
#
# ============================================================
# PROCESANDO MATERIA 246/706
# ============================================================
# 📚 Código: ADSG1029
# 📖 Nombre: TRATAMIENTO DE AGUAS
# ⏱️  [██████████--------------------] 34.7% (245/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 36 - Tiempo: 15.19s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 18 - Tiempo: 7.58s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADSG1029_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.00s
# 📊 Registros finales: 36
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 36
#    • Registros socioeconómicos: 18
#    • Cobertura socioeconómica: 50.0%
#    • Query 1: 15.19s
#    • Query 2: 7.58s
#    • Merge/Guardado: 0.00s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:48:10
# 🏁 Finalización estimada: 12:53:37
#
# ============================================================
# PROCESANDO MATERIA 247/706
# ============================================================
# 📚 Código: ADST3002
# 📖 Nombre: CIENCIAS AMBIENTALES
# ⏱️  [██████████--------------------] 34.8% (246/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 16 - Tiempo: 12.50s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 16 - Tiempo: 7.99s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/ADST3002_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.00s
# 📊 Registros finales: 16
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 16
#    • Registros socioeconómicos: 16
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 12.50s
#    • Query 2: 7.99s
#    • Merge/Guardado: 0.00s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 2:47:34
# 🏁 Finalización estimada: 12:53:22
#
# ============================================================
# PROCESANDO MATERIA 248/706
# ============================================================
# 📚 Código: AGRG1022
# 📖 Nombre: AGRICULTURA DE PRECISIÓN
# ⏱️  [██████████--------------------] 35.0% (247/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 2 - Tiempo: 12.42s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 0 - Tiempo: 9.25s
# 🔗 Realizando merge y guardando archivo...
# ❌ ERROR procesando AGRG1022: 'CODESTUDIANTE'
#
# ============================================================
# PROCESANDO MATERIA 249/706
# ============================================================
# 📚 Código: AGRG1023
# 📖 Nombre: AGROECOSISTEMAS
# ⏱️  [██████████--------------------] 35.1% (248/706)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 4 - Tiempo: 16.10s
# 🔍 Ejecutando query socioeconómico...
# ✅ Query 2 completada - Registros socioeconómicos: 3 - Tiempo: 7.82s
# 🔗 Realizando merge y guardando archivo...
# ✅ Archivo guardado: ./data/materias/AGRG1023_2024_2S.csv
# 💾 Merge y guardado - Tiempo: 0.01s
# 📊 Registros finales: 4
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos:
706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2024: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 897/706
# ============================================================
# 📚 Código: TURG2030
# 📖 Nombre: GESTIÓN HOTELERA
# ⏱️  [██████████████████████████████████████] 126.9% (896/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2030: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 898/706
# ============================================================
# 📚 Código: TURG2031
# 📖 Nombre: MARKETING TURÍSTICO
# ⏱️  [██████████████████████████████████████] 127.1% (897/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2031: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 899/706
# ============================================================
# 📚 Código: TURG2032
# 📖 Nombre: MÉTODOS DE INVESTIGACIÓN EN TURISMO
# ⏱️  [██████████████████████████████████████] 127.2% (898/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2032: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 900/706
# ============================================================
# 📚 Código: TURG2033
# 📖 Nombre: PLANIFICACIÓN DE ESPACIOS TURÍSTICOS
# ⏱️  [██████████████████████████████████████] 127.3% (899/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2033: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 901/706
# ============================================================
# 📚 Código: TURG2034
# 📖 Nombre: PATRIMONIO NATURAL Y CULTURAL
# ⏱️  [██████████████████████████████████████] 127.5% (900/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2034: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 902/706
# ============================================================
# 📚 Código: TURG2035
# 📖 Nombre: GEOGRAFÍA TURÍSTICA
# ⏱️  [██████████████████████████████████████] 127.6% (901/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2035: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 903/706
# ============================================================
# 📚 Código: TURG2036
# 📖 Nombre: TEORÍA DEL TURISMO
# ⏱️  [██████████████████████████████████████] 127.8% (902/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2036: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#
# ============================================================
# PROCESANDO MATERIA 904/706
# ============================================================
# 📚 Código: TURG2037
# 📖 Nombre: OPERACIÓN TURÍSTICA
# ⏱️  [██████████████████████████████████████] 127.9% (903/706)
#
# 🔍 Ejecutando query de historial académico...
# ❌ ERROR procesando TURG2037: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte

# %%
# Cerrar conexión
print(f"\n🔌 Cerrando conexión a la base de datos...")
ibm_db.close(conn)

# Tiempo total
end_time_total = time.time()
total_time = end_time_total - start_time_total
# Out:
# 🔌 Cerrando conexión a la base de datos...

# %%
print("\n" + "="*80)
print("RESUMEN FINAL DEL PROCESAMIENTO")
print("="*80)
print(f"🏁 Fecha y hora de finalización: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"⏱️  Tiempo total de ejecución: {format_time(total_time)}")
print(f"📊 Materias procesadas exitosamente: {total_materias - len(failed_materias)}/{total_materias}")
print(f"👥 Total estudiantes procesados: {total_students_processed:,}")
# Out:
# ================================================================================
# RESUMEN FINAL DEL PROCESAMIENTO
# ================================================================================
# 🏁 Fecha y hora de finalización: 2025-09-29 13:04:33
# ⏱️  Tiempo total de ejecución: 3:17:46
# 📊 Materias procesadas exitosamente: 476/706
# 👥 Total estudiantes procesados: 23,366

# %% [markdown]
# RESUMEN FINAL DEL PROCESAMIENTO
#
# 🏁 Fecha y hora de finalización: 2025-09-26 19:40:40
# ⏱️  Tiempo total de ejecución: 3:42:18
# 📊 Materias procesadas exitosamente: 691/706
# 👥 Total estudiantes procesados: 28,639

# %%
if processing_times:
    avg_time = sum(processing_times) / len(processing_times)
    min_time = min(processing_times)
    max_time = max(processing_times)
    
    print(f"\n📈 ESTADÍSTICAS DE TIEMPO:")
    print(f"   • Tiempo promedio por materia: {format_time(avg_time)}")
    print(f"   • Tiempo mínimo: {format_time(min_time)}")
    print(f"   • Tiempo máximo: {format_time(max_time)}")
    print(f"   • Velocidad promedio: {total_students_processed/total_time:.1f} estudiantes/segundo")
# Out:
# 📈 ESTADÍSTICAS DE TIEMPO:
#    • Tiempo promedio por materia: 0:00:26
#    • Tiempo mínimo: 0:00:14
#    • Tiempo máximo: 0:00:57
#    • Velocidad promedio: 2.0 estudiantes/segundo

# %%
if failed_materias:
    print(f"\n❌ MATERIAS CON ERRORES ({len(failed_materias)}):")
    for failed in failed_materias:
        print(f"   • {failed['codigo']} - {failed['nombre'][:50]}")
        print(f"     Error: {failed['error']}")
# Out:
# ❌ MATERIAS CON ERRORES (230):
#    • AGRG1022 - AGRICULTURA DE PRECISIÓN
#      Error: 'CODESTUDIANTE'
#    • ALIG1033 - DISEÑO DE PLANTAS ALIMENTARIAS
#      Error: 'CODESTUDIANTE'
#    • MCTG1013 - DISEÑO MECATRÓNICO
#      Error: 'utf-8' codec can't decode byte 0xe1 in position 115: invalid continuation byte
#    • MCTG1014 - DISEÑO Y MANUFACTURA ASISTIDA POR COMPUTADORA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTG1015 - DISEÑO Y SIMULACIÓN DE MÁQUINAS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTG1016 - HIDRÁULICA Y NEUMÁTICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTG1017 - INTRODUCCIÓN A LA MANUFACTURA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTG1019 - SISTEMAS BIOMECATRÓNICOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTG1020 - SISTEMAS FLEXIBLES DE MANUFACTURA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTG1021 - ROBOTS MÓVILES Y ARTICULADOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTG1022 - SISTEMAS DE MONITOREO Y CONTROL INDUSTRIAL
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTT3011 - OLEOHIDRÁULICA Y NEUMÁTICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTT3014 - MANTENIMIENTO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MCTT3015 - MONTAJE
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1041 - DIBUJO PARA INGENIERÍA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1042 - DINÁMICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1043 - DISEÑO DE SISTEMAS MECÁNICOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1044 - DISEÑO DE SISTEMAS TERMOFLUIDOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1045 - DISEÑO MECÁNICO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1046 - INSTRUMENTACIÓN
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1047 - INTRODUCCIÓN A LA INGENIERÍA MECÁNICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1048 - MANTENIMIENTO INDUSTRIAL
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1049 - MECÁNICA DE FLUIDOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1050 - MECÁNICA DE SÓLIDOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1051 - MECÁNICA DE MAQUINARIA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1052 - MECÁNICA VECTORIAL
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1053 - PROCESOS DE MANUFACTURA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1054 - TERMOFLUIDOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1055 - SISTEMAS DE CONTROL APLICADOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1056 - TURBOMAQUINARIA Y PLANTAS DE POTENCIA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1057 - PROCESOS DE MECANIZACIÓN
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1058 - TRANSFERENCIA DE CALOR
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1059 - TALLER MECÁNICO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1060 - ESTÁTICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1061 - TERMODINÁMICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1064 - TERMODINÁMICA I
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1065 - TERMODINÁMICA II
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1067 - REOLOGÍA DE FLUIDOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECG1068 - TRANSFERENCIA DE CALOR Y MASA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECT3001 - PROCESOS DE MANUFACTURA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECT3002 - ENSAMBLAJE
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECT3003 - DIBUJO TÉCNICO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECT3004 - TALLER BÁSICO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MECT3005 - ELEMENTOS DE MÁQUINAS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MEDG1015 - BIOGEOGRAFÍA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MEDG1017 - BOTÁNICA GENERAL
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • MED
S
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TLMG1033 - REDES INALÁMBRICAS Y DE SENSORES
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TLMG1034 - SISTEMAS EN LA NUBE
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TLMG1035 - TELEMETRÍA Y SISTEMAS CIBERFÍSICOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TLMG1036 - TELEMÁTICA Y TRANSFORMACIÓN DIGITAL
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TLMG1037 - PROGRAMACIÓN DE SISTEMAS TELEMÁTICOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2018 - AGENCIAS DE VIAJE
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2019 - ALIMENTOS Y BEBIDAS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2020 - CONGRESOS Y EVENTOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2021 - CONSERVACIÓN Y MANEJO AMBIENTAL EN TURISMO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2022 - DERECHO TURÍSTICO Y AMBIENTAL
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2023 - DESARROLLO SOSTENIBLE DEL TURISMO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2024 - FUNDAMENTOS DE PLANIFICACIÓN TURÍSTICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2030 - GESTIÓN HOTELERA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2031 - MARKETING TURÍSTICO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2032 - MÉTODOS DE INVESTIGACIÓN EN TURISMO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2033 - PLANIFICACIÓN DE ESPACIOS TURÍSTICOS
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2034 - PATRIMONIO NATURAL Y CULTURAL
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2035 - GEOGRAFÍA TURÍSTICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2036 - TEORÍA DEL TURISMO
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte
#    • TURG2037 - OPERACIÓN TURÍSTICA
#      Error: 'utf-8' codec can't decode byte 0xf3 in position 37: invalid continuation byte

# %% [markdown]
# ❌ MATERIAS CON ERRORES (15):
#    • ACUG1045 - PRODUCCIÓN ACUÍCOLA II
#      Error: 'CODESTUDIANTE'
#    • ALIG1033 - DISEÑO DE PLANTAS ALIMENTARIAS
#      Error: 'CODESTUDIANTE'
#    • CCPG1058 - SISTEMAS DE INFORMACIÓN APLICADOS A LOGÍSTICA
#      Error: 'CODESTUDIANTE'
#    • ESTG1056 - DATOS NO ESTRUCTURADOS
#      Error: 'CODESTUDIANTE'
#    • GEOG1027 - DISEÑO DE CAMPO GEOLÓGICO
#      Error: 'CODESTUDIANTE'
#    • GEOG1037 - INGENIERÍA GEOLÓGICA
#      Error: 'CODESTUDIANTE'
#    • INDG1061 - HSEQ EN LA INDUSTRIA HIDROCARBURÍFERA
#      Error: 'CODESTUDIANTE'
#    • MING1031 - PLANEAMIENTO Y DISEÑO MINERO
#      Error: 'CODESTUDIANTE'
#    • MTRG1027 - DISEÑO DE MATERIALES COMPUESTOS
#      Error: 'CODESTUDIANTE'
#    • MTRG1041 - NANOTECNOLOGÍA Y NANOMATERIALES
#      Error: 'CODESTUDIANTE'
#    • PETG1022 - INGENIERÍA DE PRODUCCIÓN II
#      Error: 'CODESTUDIANTE'
#    • PETG1023 - INGENIERÍA DE YACIMIENTOS I
#      Error: 'CODESTUDIANTE'
#    • PETG1024 - INGENIERÍA DE YACIMIENTOS II
#      Error: 'CODESTUDIANTE'
#    • PETG1028 - SIMULACIÓN DE RESERVORIOS
#      Error: 'CODESTUDIANTE'
#    • PETG1034 - EVALUACIÓN DE FORMACIONES II
#      Error: 'CODESTUDIANTE'

# %%
print(f"\n✅ Procesamiento completado!")
print("="*80)
# Out:
# ✅ Procesamiento completado!
# ================================================================================
