# %%
import pandas as pd

# %%
df_materias_xslx = pd.read_excel('../data/riesgo_academico/saved/TODOESPOL.xlsx')

# %%
df_materias_xslx["CodigoMateria"].nunique()
# Out:
# 726

# %%
# df_materias = pd.read_csv("../data/riesgo_academico/dificultad_materia.csv")

# %%
# df_materias["CODIGOMATERIA"].nunique()

# %%
# df_materias["CODIGOMATERIA"].value_counts()

# %%
df_new_semester = pd.read_csv("../data/riesgo_academico/all_2026_1S.csv")

# %%
df_new_semester["COD_MATERIA_ACAD_MO"].nunique()
# Out:
# 640

# %%
df_new_semester["MATERIA"].unique()
# Out:
# array(['SISTEMAS ACUÍCOLAS', 'PRODUCCIÓN ACUÍCOLA II',
#        'CULTIVO DE PLANCTON', 'ANÁLISIS DE DATOS ACUÍCOLAS',
#        'QUÍMICA GENERAL', 'INGLÉS III', 'INTRODUCCIÓN A LA ACUICULTURA',
#        'CULTIVO DE ESPECIES NO TRADICIONALES', 'PISCICULTURA',
#        'PRODUCCIÓN ACUICOLA I', 'CIENCIAS DE LA SOSTENIBILIDAD',
#        'ACUICULTURA ORNAMENTAL', 'BUENAS PRÁCTICAS EN ACUICULTURA',
#        'INGLÉS II', 'NUTRICIÓN ACUÍCOLA', 'INGLÉS V',
#        'MORFOLOGÍA Y FISIOLOGÍA DE ORGANISMOS ACUÍCOLAS',
#        'FUNDAMENTOS DE INGENIERÍA ACUÍCOLA',
#        'HERRAMIENTAS PARA EL DIAGNÓSTICO DE ENFERMEDADES ACUÍCOLAS',
#        'EMPRENDIMIENTO E INNOVACIÓN',
#        'PROBLEMAS DE LA ACTUALIDAD ACUÍCOLA', 'BIOQUÍMICA',
#        'BIOLOGÍA GENERAL', 'COMUNICACIÓN', 'CÁLCULO DE UNA VARIABLE',
#        'INGLÉS IV', 'ANÁLISIS Y RESOLUCIÓN DE PROBLEMAS',
#        'ECOSISTEMAS ACUÍCOLAS', 'PATOLOGÍA ACUÍCOLA II',
#        'PATOLOGÍA ACUÍCOLA I', 'INGENIERÍA PARA LA ACUICULTURA II',
# ...

# %%
df_materias_xslx["CodigoMateria"].nunique() - df_new_semester["COD_MATERIA_ACAD_MO"].nunique()
# Out:
# 86

# %%
df_materias_xslx_faltantes = df_materias_xslx[~df_materias_xslx["CodigoMateria"].isin(df_new_semester["COD_MATERIA_ACAD_MO"].unique())].copy()
df_materias_xslx_faltantes["NombreMateria"]
# Out:
# 20                    MATERIA INTEGRADORA DE ACUICULTURA
# 22                           EMPRENDIMIENTO E INNOVACIÓN
# 23     GESTIÓN DE PROYECTOS Y REGULACIÓN EN TELECOMUN...
# 24                                ESTRATEGIAS DE GESTIÓN
# 25                         ADMINISTRACIÓN DE OPERACIONES
#                              ...
# 675            MATERIA INTEGRADORA DE INGENIERÍA QUÍMICA
# 686            MATERIA INTEGRADORA DE TELECOMUNICACIONES
# 695                             BASES DE DATOS AVANZADAS
# 703                    MATERIA INTEGRADORA DE TELEMÁTICA
# 717                       MATERIA INTEGRADORA DE TURISMO
# Name: NombreMateria, Length: 86, dtype: object

# %%
missing_rows = df_materias_xslx[
    ~df_materias_xslx["CodigoMateria"].isin(df_new_semester["COD_MATERIA_ACAD_MO"])
]

len(missing_rows)  # filas (posible 86)
missing_rows["CodigoMateria"].nunique()  # códigos únicos faltantes (posible 70)
# Out:
# 86

# %%
faltan_en_new = set(df_materias_xslx["CodigoMateria"].dropna().astype(str).str.strip()) - \
                set(df_new_semester["COD_MATERIA_ACAD_MO"].dropna().astype(str).str.strip())

len(faltan_en_new)
# Out:
# 86

# %%
# ADMG2035  este da error

# %%
lista_error = ['EYAT3004', 'MING1029', 'MING1036', 'GEOG1038', 'LOGG1021', 'AUDG2044', 'ESTG1055', 'AGRG1040', 'NAVT3001', 'GEOG1051', 'LOGT3002', 'CCPG1041', 'GEOG1028', 'TLMG1026', 'MATG1077', 'NAVG1027', 'GEOG1029', 'MING1027', 'MECT3002', 'ESTG1049', 'OCEG1047', 'ARQG2028', 'GEOG1035', 'MING1041', 'MING1024', 'ESTG1057', 'MING1034', 'ARQG2036', 'OCEG1029', 'OCEG1029', 'OCEG1029', 'OCEG1029', 'OCEG1049', 'TELG1029', 'CCPT3004', 'OCEG1040', 'ELET3001', 'MATG1074', 'LOGG1022', 'AGRG1030', 'MECT3003', 'MCTT3011', 'EYAT3002', 'ESTG1050', 'ARQG2029', 'ESTT3002', 'LOGT3010', 'ARQG2023', 'MCTT3015', 'MATG1071', 'LOGT3009', 
               'OCEG1033', 'LOGT3006', 'IDIT3004', 'LOGG1024', 'OCEG1034', 'MING1033', 'MATG1060', 'LOGG1020', 'NAVT3003', 'OCEG1035', 'PETG1021', 'MING1025', 'ARQG2030', 'MATG1067', 'OCEG1031', 'OCEG1046', 'LOGG1023', 'OCEG1051', 'GEOG1048', 'INDG1060', 'ARQG2022', 'EYAT3003', 'ESTG1054', 'OCET3002', 'ELET3002', 'TELG1034', 'OCEG1039', 'ARQG2043', 'AGRG1022', 'JURG2005', 'OCEG1038', 'ESTG1047', 'ECOG2058', 'TELG1038', 'ESTG1048', 'LOGT3012', 'MING1040', 'LOGT3011', 'ESTG1033', 'MATG1069', 'IDIT3003', 'NAVG1031', 'TURG2030', 'MCTT3014', 'LOGT3013', 'AGRG1028', 'ADST3002', 'TURG2031', 'GEOG1040', 'NAVG1025', 'NAVT3002', 'ECOG1008', 'TLMG1025', 'LOGT3007']

lista_error = ['ACUG1058', 'ADMG1005', 'ADMG1006', 'ADMG1007', 'ADMG2022', 'ADMG2024', 'ADMG2025', 'ADMG2026', 'ADMG2028', 'ADMG2029', 'ADMG2030', 'ADMG2031', 'ADMG2032', 'ADMG2033', 'ADMG2034', 'ADMG2035', 'ADMG2036', 'ADMG2037', 'ADMT3004', 'ADMT3004', 'ADST3002', 'ADST3002', 'AGRG1022', 'AGRG1028', 'AGRG1029', 'AGRG1030', 'AGRG1040', 'ALIG1040', 'ARQG2022', 'ARQG2023', 'ARQG2024', 'ARQG2028', 'ARQG2030', 'ARQG2036', 'ARQG2043', 'AUDG2040', 'BIOG1027', 'CADG2043', 'CCPG1035', 'CCPT3004', 'CCPT3004', 'CDIAG1001', 'CDIAG1001', 'CDIAG1002', 'CDIAG1002', 'CDIAG1003', 'CDIAG1802', 'CDIAG1802', 'CDIAG1804', 'CDIAG1804', 'CDIAG1806', 'CDIAG1806', 'CDIAG1807', 
               'CDIAG1807', 'CDIAG1808', 'CDIAG1808', 'CDIAG1809', 'CDIAG1809', 'CIVG1054', 'DIGG2034', 'DING2032', 'ECOG1008', 'ECOG2053', 'ELEG1042', 'ELET3001', 'ELET3001', 'ELET3002', 'ELET3002', 'ESTG1047', 'ESTG1048', 'ESTG1049', 'ESTG1050', 'ESTG1055', 'ESTG1057', 'ESTG1062', 'ESTG1801', 'ESTG1801', 'ESTT3002', 'ESTT3002', 'EYAG1039', 'EYAT3002', 'EYAT3003', 'EYAT3004', 'EYAT3004', 'GEOG1028', 'GEOG1029', 'GEOG1035', 'GEOG1038', 'GEOG1039', 'GEOG1040', 'GEOG1048', 'GEOG1051', 'IDIG1801', 'IDIG1801', 'IDIT3003', 'IDIT3003', 'IDIT3004', 'IDIT3004', 'INDG1043', 'LOGG1020', 'LOGG1023', 'LOGG1024', 'LOGG1027', 'LOGT3002', 'LOGT3002', 'LOGT3006', 'LOGT3006', 
               'LOGT3007', 'LOGT3007', 'LOGT3009', 'LOGT3009', 'LOGT3010', 'LOGT3010', 'LOGT3011', 'LOGT3011', 'LOGT3012', 'LOGT3012', 'LOGT3013', 'LOGT3013', 'LOGT3014', 'LOGT3014', 'MATG1060', 'MATG1067', 'MATG1069', 'MATG1071', 'MATG1074', 'MATG1077', 'MATG1086', 'MCTG1028', 'MCTT3011', 'MCTT3014', 'MCTT3014', 'MCTT3015', 'MCTT3015', 'MCTT3017', 'MCTT3017', 'MECG1066', 'MECT3002', 'MECT3003', 'MECT3003', 'MING1024', 'MING1025', 'MING1027', 'MING1029', 'MING1033', 'MING1034', 'MING1040', 'MING1041', 'MTRG1034', 'NAVG1025', 'NAVG1027', 'NAVG1031', 'NAVG1034', 'NAVT3001', 'NAVT3001', 'NAVT3002', 'NAVT3002', 'NAVT3003', 'NAVT3003', 'NUTG2031', 'OCEG1033', 'OCEG1035', 
               'OCEG1038', 'OCEG1039', 'OCEG1040', 'OCEG1043', 'OCEG1043', 'OCEG1046', 'OCEG1047', 'OCEG1049', 'OCEG1051', 'OCET3002', 'OCET3002', 'PETG1021', 'PETG1033', 'QUIG1050', 'TELG1033', 'TELG1034', 'TELG1038', 'TICG1801', 'TICG1801', 'TLMG1025', 'TLMG1026', 'TLMG1031', 'TURG2029']

# %%
len(lista_error)
# Out:
# 185

# %%
df_materias_xslx["CodigoMateria"].nunique()-len(lista_error)
# Out:
# 541

# %% [markdown]
# hay una materia que aprobaron todos y nadie a visto la prerequisito, entonces no tiene estudiantes nuevos
# EYAT3004, MECT3003

# %%
G2031', 'ESTG1049', 'MCTG1013', 'PETG1023', 'QUIG1046', 'ESTG1054', 'MECG1059', 'TLMG1035', 'ARQG2028', 'ECOG2044', 'EYAG1042', 'MATG1051', 'MECG1065', 'MATG1048', 'ELET3001', 'MCTG1016', 'GEOG1030', 'NUTG2026', 'ARQG2029', 'GEOG1032', 'MECG1049', 'CADG2040', 'GEOG1038', 'DIGG2032', 'ELEG1047', 'QUIG1032', 'ARQG2038', 'ALIG1038', 'MTRG1028', 'NUTG2034', 'CCAG2022', 'MCTT3014', 'MATG1050', 'ELEG1032', 'MING1035', 'AGRG1038', 'DING2039', 'ELEG1049', 'ESTG1037', 'MTRG1029', 'OCEG1050', 'OCEG1036', 'ADSG1025', 'CIVG1056', 'MING1027', 'AUDG2044', 'LOGG1017', 'ALIG1031', 'GEOG1037', 'TELG1042', 'TLMG1027', 'ESTG1040', 'INDG1056', 'CADG2039', 'CIVG1059', 'CIVG1058', 'MATG1064', 'ACUG1057', 'ECOG2049', 'CCPG1044', 'ESTG1036', 'MCTG1014', 'FISG1005', 'NUTG2037', 'ESTG1041', 'EYAT3002', 'MATG1802', 'ARQG2026', 'QUIG1033', 'TLMG1037', 'TURG2020', 'MING1024', 'ELEG1041', 'DING2031', 'CCPG1049', 'OCEG1046', 'QUIG1040', 'MEDG1022', 'ADSG1019', 'OCEG1033', 'ECOG2066', 'QUIG1036', 'SOFG1009', 'IDIT3002', 'OCEG1047', 'CIVG1038', 'QUIG1041', 'LOGG1020', 'DIGG2030', 'TELG1035', 'ALIG1050', 'DIGG2031', 'MCTT3015', 'ACUG1047', 'TURG2023', 'JURG2004', 'ARTG2026', 'CCPG1059', 'ELEG1029', 'DING2026', 'NUTG2033', 'INDG1045', 'CIVG1050', 'ALIG1042', 'DING2040', 'MECT3004', 'TLMG1029', 'NAVG1039', 'ELEG1044', 'MATG1801', 'ACUG1035', 'MCTG1020', 'TURG2021', 'ESTG1034', 'NAVG1027', 'INDG1042', 'INDG1046', 'INDG1058', 'MTRG1026', 'MTRG1027', 'GEOG1048', 'ACUG1056', 'ELEG1040', 'CCPG1036', 'ALIG1030', 'TELG1040']

# %%
# join entre lista_error y list_encoder para obtener los elementos que están en lista_error y en list_encoder
lista_error_encoder = list(set(lista_error) & set(list_encoder))

# %%
len(lista_error_encoder)
# Out:
# 85

# %%
lista_error_encoder
# Out:
# ['LOGG1020',
#  'MATG1069',
#  'OCEG1039',
#  'MING1024',
#  'AGRG1022',
#  'MING1040',
#  'ARQG2022',
#  'ARQG2043',
#  'OCEG1040',
#  'MATG1060',
#  'EYAT3004',
#  'ESTG1050',
#  'MATG1077',
#  'OCET3002',
#  'LOGT3007',
#  'EYAT3002',
#  'MING1034',
#  'LOGT3002',
#  'MATG1067',
#  'OCEG1047',
#  'GEOG1051',
#  'MATG1074',
#  'ESTG1057',
#  'MECT3003',
#  'IDIT3004',
#  'PETG1021',
#  'NAVT3003',
#  'GEOG1038',
#  'LOGG1024',
#  'MING1041',
#  'TELG1038',
#  'MATG1071',
#  'ELET3002',
#  'EYAT3003',
#  'IDIT3003',
#  'MING1033',
#  'GEOG1035',
#  'GEOG1040',
#  'MING1025',
#  'ESTG1055',
#  'OCEG1038',
#  'TLMG1026',
#  'AGRG1030',
#  'MCTT3015',
#  'OCEG1035',
#  'AGRG1040',
#  'NAVT3002',
#  'LOGT3010',
#  'TLMG1025',
#  'TELG1034',
#  'NAVT3001',
#  'LOGT3011',
#  'LOGG1023',
#  'AGRG1028',
#  'OCEG1046',
#  'GEOG1048',
#  'ARQG2028',
#  'LOGT3009',
#  'LOGT3012',
#  'GEOG1028',
#  'OCEG1051',
#  'NAVG1027',
#  'ECOG1008',
#  'ESTG1047',
#  'OCEG1049',
#  'MING1027',
# ...

# %%
df_materias_xslx_faltantes_encoder = df_materias_xslx[df_materias_xslx["CodigoMateria"].isin(lista_error_encoder)].copy()
df_materias_xslx_faltantes_encoder[["CodigoMateria", "NombreMateria"]]
# Out:
#     CodigoMateria                                   NombreMateria
# 49       ADST3002                            CIENCIAS AMBIENTALES
# 50       AGRG1022                        AGRICULTURA DE PRECISIÓN
# 56       AGRG1028  GESTIÓN DE UNIDADES DE PRODUCCIÓN AGROPECUARIA
# 58       AGRG1030                           MECANIZACIÓN AGRÍCOLA
# 66       AGRG1040                          PRODUCCIÓN VEGETAL III
# ..            ...                                             ...
# 647      PETG1021                      INGENIERÍA DE PRODUCCIÓN I
# 687      TELG1034                PROCESAMIENTO DIGITAL DE SEÑALES
# 690      TELG1038                    SISTEMAS DE COMUNICACIONES I
# 697      TLMG1025          CALIDAD DE SERVICIO Y REDES MULTIMEDIA
# 698      TLMG1026               CIBERSEGURIDAD Y GESTIÓN DE REDES
#
# [85 rows x 2 columns]

# %%
# in df_materias_xslx_faltantes and not in df_materias_xslx_faltantes_encoder
faltantes_no_encoder = set(df_materias_xslx_faltantes["CodigoMateria"]) - set(df_materias_xslx_faltantes_encoder["CodigoMateria"])
df_materias_xslx_faltantes_no_encoder = df_materias_xslx[df_materias_xslx["CodigoMateria"].isin(faltantes_no_encoder)].copy()
df_materias_xslx_faltantes_no_encoder[["CodigoMateria", "NombreMateria"]]
# Out:
#     CodigoMateria                                      NombreMateria
# 20       ACUG1058                 MATERIA INTEGRADORA DE ACUICULTURA
# 22       ADMG1005                        EMPRENDIMIENTO E INNOVACIÓN
# 23       ADMG1006  GESTIÓN DE PROYECTOS Y REGULACIÓN EN TELECOMUN...
# 24       ADMG1007                             ESTRATEGIAS DE GESTIÓN
# 25       ADMG2022                      ADMINISTRACIÓN DE OPERACIONES
# ..            ...                                                ...
# 675      QUIG1050          MATERIA INTEGRADORA DE INGENIERÍA QUÍMICA
# 686      TELG1033          MATERIA INTEGRADORA DE TELECOMUNICACIONES
# 695      TICG1801                           BASES DE DATOS AVANZADAS
# 703      TLMG1031                  MATERIA INTEGRADORA DE TELEMÁTICA
# 717      TURG2029                     MATERIA INTEGRADORA DE TURISMO
#
# [62 rows x 2 columns]

# %%
df_2026_1S = pd.read_csv('../data\\riesgo_academico\\PAO_2026_1S.csv')

# %%
df_2026_1S["COD_MATERIA_ACAD_MO"].nunique()
# Out:
# 640
