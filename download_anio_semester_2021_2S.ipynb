# %%
import os
import time
from datetime import datetime, timedelta

# %%
os.add_dll_directory('C:\\Program Files\\IBM\\SQLLIB\\BIN')
# conectar a la base de datos IBM Db2
import ibm_db

# %%
from queries import get_academic_history, get_socioeconomico, tasa_reprobacion, dificultad_materia
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def format_time(seconds):
    """Convierte segundos a formato HH:MM:SS"""
    return str(timedelta(seconds=int(seconds)))

def print_progress_bar(current, total, bar_length=30):
    """Imprime una barra de progreso"""
    percent = float(current) * 100 / total
    filled_length = int(bar_length * current // total)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    return f'[{bar}] {percent:.1f}% ({current}/{total})'

# %%
print("="*80)
print("INICIO DE DESCARGA DE DATOS ACADÉMICOS")
print("="*80)
print(f"Fecha y hora de inicio: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ================================================================================
# INICIO DE DESCARGA DE DATOS ACADÉMICOS
# ================================================================================
# Fecha y hora de inicio: 2025-10-08 08:18:40

# %%
# Tiempo de inicio total
start_time_total = time.time()

print("\n📡 Conectando con la base de datos...")
start_time_conn = time.time()
# Out:
# 📡 Conectando con la base de datos...

# %%
conn_str = (
    'DATABASE=' + os.getenv('DATABASE') + 
    ';HOSTNAME=' + os.getenv('HOSTNAME') + 
    ';PORT=' + os.getenv('PORT') + 
    ';PROTOCOL=TCPIP;UID=' + os.getenv('USERNAME_DB') + 
    ';PWD=' + os.getenv('PASSWORD_DB') + ';'
)

print(repr(conn_str))
conn = ibm_db.connect(conn_str, '', '')
# Out:
# 'DATABASE=SAAC;HOSTNAME=192.168.254.53;PORT=50000;PROTOCOL=TCPIP;UID=espol;PWD=espol123;'

# %%
end_time_conn = time.time()
connection_time = end_time_conn - start_time_conn

if conn:
    print(f"✅ Conexión exitosa - Tiempo: {connection_time:.2f} segundos")
else:
    print("❌ Error al conectar")
    exit(1)
# Out:
# ✅ Conexión exitosa - Tiempo: 33.90 segundos

# %%
# Cargar datos de materias
print("\n📁 Cargando lista de materias...")
start_time_load = time.time()
df_materias = pd.read_csv("./data/materias/dificultad_materia.csv")
end_time_load = time.time()
load_time = end_time_load - start_time_load

print(f"✅ Materias cargadas - Tiempo: {load_time:.2f} segundos")
print(f"📊 Total de materias en archivo: {len(df_materias)}")
# Out:
# 📁 Cargando lista de materias...
# ✅ Materias cargadas - Tiempo: 0.00 segundos
# 📊 Total de materias en archivo: 1926

# %%
# # Filtrar materias a procesar
# list_not_grades = ["PORTAFOLIO"]
# materias_to_process = []

# for i in df_materias.iterrows():
#     if i[1]["MATERIA_x"] in list_not_grades or "MATERIA INTEGRADORA" in i[1]["MATERIA_x"]:
#         continue
#     materias_to_process.append(i[1])
materias_to_process = df_materias[df_materias["CLASIFMATERIA"] == "G"]

# %%
total_materias = len(materias_to_process)
print(f"🎯 Materias a procesar: {total_materias}")

# Parámetros de configuración
year = "2021"
semester = "2S"
print(f"📅 Período: {year} - {semester}")
# Out:
# 🎯 Materias a procesar: 1892
# 📅 Período: 2021 - 2S

# %%
print("\n" + "="*80)
print("INICIANDO PROCESAMIENTO DE MATERIAS")
print("="*80)

# Variables para estadísticas
total_students_processed = 0
failed_materias = []
processing_times = []
df_complete = pd.DataFrame()
# Out:
# ================================================================================
# INICIANDO PROCESAMIENTO DE MATERIAS
# ================================================================================

# %%
# Procesar cada materia
# for counter, materia_data in enumerate(materias_to_process, 1):
for counter, materia_data in materias_to_process.iterrows():
    counter += 1
    print(counter, materia_data)
    print(f"\n{'='*60}")
    print(f"PROCESANDO MATERIA {counter}/{total_materias}")
    print(f"{'='*60}")
    
    cod_materia = materia_data["CODIGOMATERIA"].strip()
    # materia_name = materia_data["MATERIA_x"]
    materia_name = materia_data["MATERIA"].strip()
    
    print(f"📚 Código: {cod_materia}")
    print(f"📖 Nombre: {materia_name}")
    print(f"⏱️  {print_progress_bar(counter-1, total_materias)}")
    
    # Tiempo de inicio para esta materia
    start_time_materia = time.time()
    
    try:
        # Query 1: Historial académico
        print(f"\n🔍 Ejecutando query de historial académico...")
        start_time_query1 = time.time()
        
        query = get_academic_history(cod_materia, year, semester)
        stmt_select = ibm_db.exec_immediate(conn, query)
        
        data_list = []
        result = ibm_db.fetch_assoc(stmt_select)
        while result:
            result["COD_MATERIA_ACAD_MO"] = result["COD_MATERIA_ACAD_MO"].strip()
            result["CODIGOMATERIA"] = cod_materia
            result["MATERIA"] = materia_name
            data_list.append(result)
            result = ibm_db.fetch_assoc(stmt_select)
        
        df = pd.DataFrame(data_list)
        end_time_query1 = time.time()
        query1_time = end_time_query1 - start_time_query1
        
        num_students = len(df)
        print(f"✅ Query 1 completada - Estudiantes encontrados: {num_students} - Tiempo: {query1_time:.2f}s")
        
        if num_students == 0:
            print(f"⚠️  No hay estudiantes para esta materia, saltando...")
            continue
        
        # # Query 2: Datos socioeconómicos
        # print(f"🔍 Ejecutando query socioeconómico...")
        # start_time_query2 = time.time()

        # query = get_socioeconomico(df["COD_ESTUDIANTE"].to_list())
        # stmt_select = ibm_db.exec_immediate(conn, query)

        # data_list = []
        # result = ibm_db.fetch_assoc(stmt_select)
        # while result:
        #     data_list.append(result)
        #     result = ibm_db.fetch_assoc(stmt_select)

        # df_socio = pd.DataFrame(data_list)
        # end_time_query2 = time.time()
        # query2_time = end_time_query2 - start_time_query2

        # socio_records = len(df_socio)
        socio_records = len(df)
        # print(f"✅ Query 2 completada - Registros socioeconómicos: {socio_records} - Tiempo: {query2_time:.2f}s")

        # if df_socio.empty:
        #     print(f"⚠️ No se encontraron datos socioeconómicos de {len(df["COD_ESTUDIANTE"])} estudiante/s. Se crearán columnas vacías.")
        #     df_socio = pd.DataFrame(columns=['CODESTUDIANTE']) # Asegura que la columna exista.


        # # Merge y guardado
        # print(f"🔗 Realizando merge y guardando archivo...")
        # start_time_merge = time.time()

        # df["COD_ESTUDIANTE"] = df["COD_ESTUDIANTE"].astype(str).str.strip()
        # df_socio["CODESTUDIANTE"] = df_socio["CODESTUDIANTE"].astype(str).str.strip()

        # df_merge = pd.merge(df, df_socio, left_on='COD_ESTUDIANTE', right_on="CODESTUDIANTE", how='left')

        # if "CODESTUDIANTE" in df_merge.columns:
        #     df_merge.drop("CODESTUDIANTE", axis=1, inplace=True)
            
        # df_complete = pd.concat([df_complete, df_merge], ignore_index=True)
        df_complete = pd.concat([df_complete, df], ignore_index=True)

        end_time_merge = time.time()
        # merge_time = end_time_merge - start_time_merge

        # Tiempo total para esta materia
        end_time_materia = time.time()
        materia_time = end_time_materia - start_time_materia
        processing_times.append(materia_time)
        
        
        # print(f"💾 Merge y guardado - Tiempo: {merge_time:.2f}s")
        # print(f"📊 Registros finales: {len(df_merge)}")
        
        # Estadísticas de la materia
        total_students_processed += num_students
        coverage = (socio_records / num_students * 100) if num_students > 0 else 0
        
        print(f"\n📈 RESUMEN MATERIA:")
        print(f"   • Estudiantes académicos: {num_students}")
        # print(f"   • Registros socioeconómicos: {socio_records}")
        print(f"   • Cobertura socioeconómica: {coverage:.1f}%")
        print(f"   • Query 1: {query1_time:.2f}s")
        # print(f"   • Query 2: {query2_time:.2f}s")
        # print(f"   • Merge/Guardado: {merge_time:.2f}s")
        print(f"   • Tiempo total materia: {format_time(materia_time)}")
        
        # Estimación de tiempo restante
        if len(processing_times) >= 3:  # Solo después de procesar al menos 3 materias
            avg_time_per_materia = sum(processing_times) / len(processing_times)
            remaining_materias = total_materias - counter
            estimated_remaining_time = avg_time_per_materia * remaining_materias
            
            print(f"⏰ Tiempo promedio por materia: {format_time(avg_time_per_materia)}")
            print(f"⏳ Tiempo estimado restante: {format_time(estimated_remaining_time)}")
            
            estimated_finish = datetime.now() + timedelta(seconds=estimated_remaining_time)
            print(f"🏁 Finalización estimada: {estimated_finish.strftime('%H:%M:%S')}")
        
        # if counter == 2:
        #     break
    except Exception as e:
        print(f"❌ ERROR procesando {cod_materia}: {str(e)}")
        failed_materias.append({
            'codigo': cod_materia,
            # 'nombre': materia_name,
            'error': str(e)
        })
# Out:
# 1 CODIGOMATERIA                  ACUG1035
# CLASIFMATERIA                         G
# MATERIA          ACUICULTURA ORNAMENTAL
# ANIO                               2020
# TERMINO                              0S
# DIFICULTAD                         8,52
# Name: 0, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1/1892
# ============================================================
# 📚 Código: ACUG1035
# 📖 Nombre: ACUICULTURA ORNAMENTAL
# ⏱️  [------------------------------] 0.0% (0/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 8 - Tiempo: 18.69s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 8
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 18.69s
#    • Tiempo total materia: 0:00:18
# 2 CODIGOMATERIA                       ACUG1036
# CLASIFMATERIA                              G
# MATERIA          ANÁLISIS DE DATOS ACUÍCOLAS
# ANIO                                    2020
# TERMINO                                   0S
# DIFICULTAD                              7,72
# Name: 1, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 2/1892
# ============================================================
# 📚 Código: ACUG1036
# 📖 Nombre: ANÁLISIS DE DATOS ACUÍCOLAS
# ⏱️  [------------------------------] 0.1% (1/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 20.47s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 20.47s
#    • Tiempo total materia: 0:00:20
# 3 CODIGOMATERIA                                ACUG1039
# CLASIFMATERIA                                       G
# MATERIA          CULTIVO DE ESPECIES NO TRADICIONALES
# ANIO                                             2020
# TERMINO                                            0S
# DIFICULTAD                                       8,63
# Name: 2, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 3/1892
# ============================================================
# 📚 Código: ACUG1039
# 📖 Nombre: CULTIVO DE ESPECIES NO TRADICIONALES
# ⏱️  [------------------------------] 0.1% (2/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 21.47s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 21.47s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:20
# ⏳ Tiempo estimado restante: 10:36:16
# 🏁 Finalización estimada: 18:56:31
# 4 CODIGOMATERIA               ACUG1040
# CLASIFMATERIA                      G
# MATERIA          CULTIVO DE PLANCTON
# ANIO                            2020
# TERMINO                           0S
# DIFICULTAD                      8,25
# Name: 3, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 4/1892
# ============================================================
# 📚 Código: ACUG1040
# 📖 Nombre: CULTIVO DE PLANCTON
# ⏱️  [------------------------------] 0.2% (3/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 11 - Tiempo: 21.66s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 11
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 21.66s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:20
# ⏳ Tiempo estimado restante: 10:47:26
# 🏁 Finalización estimada: 19:08:03
# 5 CODIGOMATERIA                 ACUG1041
# CLASIFMATERIA                        G
# MATERIA          ECOSISTEMAS ACUÍCOLAS
# ANIO                              2020
# TERMINO                             0S
# DIFICULTAD                        7,41
# Name: 4, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 5/1892
# ============================================================
# 📚 Código: ACUG1041
# 📖 Nombre: ECOSISTEMAS ACUÍCOLAS
# ⏱️  [------------------------------] 0.2% (4/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 1 - Tiempo: 18.63s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 1
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 18.63s
#    • Tiempo total materia: 0:00:18
# ⏰ Tiempo promedio por materia: 0:00:20
# ⏳ Tiempo estimado restante: 10:34:52
# 🏁 Finalización estimada: 18:55:48
# 6 CODIGOMATERIA                              ACUG1042
# CLASIFMATERIA                                     G
# MATERIA          FUNDAMENTOS DE INGENIERÍA ACUÍCOLA
# ANIO                                           2020
# TERMINO                                          0S
# DIFICULTAD                                     8,38
# Name: 5, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 6/1892
# ============================================================
# 📚 Código: ACUG1042
# 📖 Nombre: FUNDAMENTOS DE INGENIERÍA ACUÍCOLA
# ⏱️  [------------------------------] 0.3% (5/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 19.00s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 19.00s
#    • Tiempo total materia: 0:00:19
# ⏰ Tiempo promedio por materia: 0:00:19
# ⏳ Tiempo estimado restante: 10:28:19
# 🏁 Finalización estimada: 18:49:34
# 7 CODIGOMATERIA                                             ACUG1043
# CLASIFMATERIA                                                    G
# MATERIA          HERRAMIENTAS PARA EL DIAGNÓSTICO DE ENFERMEDAD...
# ANIO                                                          2020
# TERMINO                                                         0S
# DIFICULTAD                                                    7,90
# Name: 6, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 7/1892
# ============================================================
# 📚 Código: ACUG1043
# 📖 Nombre: HERRAMIENTAS PARA EL DIAGNÓSTICO DE ENFERMEDADES ACUÍCOLAS
# ⏱️  [------------------------------] 0.3% (6/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 19 - Tiempo: 20.42s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 19
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 20.42s
#    • Tiempo total materia: 0:00:20
# ⏰ Tiempo promedio por materia: 0:00:20
# ⏳ Tiempo estimado restante: 10:29:56
# 🏁 Finalización estimada: 18:51:31
# 8 CODIGOMATERIA                  ACUG1045
# CLASIFMATERIA                         G
# MATERIA          PRODUCCIÓN ACUÍCOLA II
# ANIO                               2020
# TERMINO                              0S
# DIFICULTAD                         8,32
# Name: 7, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 8/1892
# ============================================================
# 📚 Código: ACUG1045
# 📖 Nombre: PRODUCCIÓN ACUÍCOLA II
# ⏱️  [------------------------------] 0.4% (7/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 25 - Tiempo: 21.35s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 25
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 21.35s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:20
# ⏳ Tiempo estimado restante: 10:34:43
# 🏁 Finalización estimada: 18:56:39
# 9 CODIGOMATERIA                 ACUG1046
# CLASIFMATERIA                        G
# MATERIA          PRODUCCIÓN ACUICOLA I
# ANIO                              2020
# TERMINO                             0S
# DIFICULTAD                        8,62
# Name: 8, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 9/1892
# ============================================================
# 📚 Código: ACUG1046
# 📖 Nombre: PRODUCCIÓN ACUICOLA I
# ⏱️  [------------------------------] 0.4% (8/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 15 - Tiempo: 26.83s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 15
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.83s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:20
# ⏳ Tiempo estimado restante: 10:57:28
# 🏁 Finalización estimada: 19:19:51
# 10 CODIGOMATERIA        ACUG1047
# CLASIFMATERIA               G
# MATERIA          PISCICULTURA
# ANIO                     2020
# TERMINO                    0S
# DIFICULTAD               8,78
# Name: 9, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 10/1892
# ============================================================
# 📚 Código: ACUG1047
# 📖 Nombre: PISCICULTURA
# ⏱️  [------------------------------] 0.5% (9/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 14 - Tiempo: 24.76s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 14
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 24.76s
#    • Tiempo total materia: 0:00:24
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 11:09:05
# 🏁 Finalización estimada: 19:31:53
# 11 CODIGOMATERIA              ACUG1048
# CLASIFMATERIA                     G
# MATERIA          SISTEMAS ACUÍCOLAS
# ANIO                           2020
# TERMINO                          0S
# DIFICULTAD                     8,38
# Name: 10, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 11/1892
# ============================================================
# 📚 Código: ACUG1048
# 📖 Nombre: SISTEMAS ACUÍCOLAS
# ⏱️  [------------------------------] 0.5% (10/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 17 - Tiempo: 25.25s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 17
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 25.25s
#    • Tiempo total materia: 0:00:25
# ⏰ Tiempo promedio por materia: 0:00:21
# ⏳ Tiempo estimado restante: 11:19:55
# 🏁 Finalización estimada: 19:43:09
# 12 CODIGOMATERIA                             ACUG1049
# CLASIFMATERIA                                    G
# MATERIA          INGENIERÍA PARA LA ACUICULTURA II
# ANIO                                          2020
# TERMINO                                         0S
# DIFICULTAD                                    6,79
# Name: 11, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 12/1892
# ============================================================
# 📚 Código: ACUG1049
# 📖 Nombre: INGENIERÍA PARA LA ACUICULTURA II
# ⏱️  [------------------------------] 0.6% (11/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 25.71s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 25.71s
#    • Tiempo total materia: 0:00:25
# ⏰ Tiempo promedio por materia: 0:00:22
# ⏳ Tiempo estimado restante: 11:30:04
# 🏁 Finalización estimada: 19:53:43
# 13 CODIGOMATERIA                            ACUG1050
# CLASIFMATERIA                                   G
# MATERIA          INGENIERÍA PARA LA ACUICULTURA I
# ANIO                                         2020
# TERMINO                                        0S
# DIFICULTAD                                   6,74
# Name: 12, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 13/1892
# ============================================================
# 📚 Código: ACUG1050
# 📖 Nombre: INGENIERÍA PARA LA ACUICULTURA I
# ⏱️  [------------------------------] 0.6% (12/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 25.37s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 25.37s
#    • Tiempo total materia: 0:00:25
# ⏰ Tiempo promedio por materia: 0:00:22
# ⏳ Tiempo estimado restante: 11:37:46
# 🏁 Finalización estimada: 20:01:51
# 14 CODIGOMATERIA              ACUG1051
# CLASIFMATERIA                     G
# MATERIA          NUTRICIÓN ACUÍCOLA
# ANIO                           2020
# TERMINO                          0S
# DIFICULTAD                     7,89
# Name: 13, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 14/1892
# ============================================================
# 📚 Código: ACUG1051
# 📖 Nombre: NUTRICIÓN ACUÍCOLA
# ⏱️  [------------------------------] 0.7% (13/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 9 - Tiempo: 26.53s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 9
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.53s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:22
# ⏳ Tiempo estimado restante: 11:46:54
# 🏁 Finalización estimada: 20:11:25
# 15 CODIGOMATERIA                                           ACUG1052
# CLASIFMATERIA                                                  G
# MATERIA          MORFOLOGÍA Y FISIOLOGÍA DE ORGANISMOS ACUÍCOLAS
# ANIO                                                        2020
# TERMINO                                                       0S
# DIFICULTAD                                                  8,46
# Name: 14, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 15/1892
# ============================================================
# 📚 Código: ACUG1052
# 📖 Nombre: MORFOLOGÍA Y FISIOLOGÍA DE ORGANISMOS ACUÍCOLAS
# ⏱️  [------------------------------] 0.7% (14/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 9 - Tiempo: 25.90s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 9
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 25.90s
#    • Tiempo total materia: 0:00:25
# ⏰ Tiempo promedio por materia: 0:00:22
# ⏳ Tiempo estimado restante: 11:53:26
# 🏁 Finalización estimada: 20:18:23
# 16 CODIGOMATERIA           ACUG1053
# CLASIFMATERIA                  G
# MATERIA          MANEJO ACUÍCOLA
# ANIO                        2020
# TERMINO                       0S
# DIFICULTAD                  7,19
# Name: 15, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 16/1892
# ============================================================
# 📚 Código: ACUG1053
# 📖 Nombre: MANEJO ACUÍCOLA
# ⏱️  [------------------------------] 0.8% (15/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 9 - Tiempo: 25.73s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 9
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 25.73s
#    • Tiempo total materia: 0:00:25
# ⏰ Tiempo promedio por materia: 0:00:22
# ⏳ Tiempo estimado restante: 11:58:46
# 🏁 Finalización estimada: 20:24:08
# 17 CODIGOMATERIA                         ACUG1054
# CLASIFMATERIA                                G
# MATERIA          INTRODUCCIÓN A LA ACUICULTURA
# ANIO                                      2020
# TERMINO                                     0S
# DIFICULTAD                                7,90
# Name: 16, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 17/1892
# ============================================================
# 📚 Código: ACUG1054
# 📖 Nombre: INTRODUCCIÓN A LA ACUICULTURA
# ⏱️  [------------------------------] 0.8% (16/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 1 - Tiempo: 24.59s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 1
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 24.59s
#    • Tiempo total materia: 0:00:24
# ⏰ Tiempo promedio por materia: 0:00:23
# ⏳ Tiempo estimado restante: 12:01:19
# 🏁 Finalización estimada: 20:27:07
# 18 CODIGOMATERIA                               ACUG1055
# CLASIFMATERIA                                      G
# MATERIA          PROBLEMAS DE LA ACTUALIDAD ACUÍCOLA
# ANIO                                            2020
# TERMINO                                           0S
# DIFICULTAD                                      8,33
# Name: 17, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 18/1892
# ============================================================
# 📚 Código: ACUG1055
# 📖 Nombre: PROBLEMAS DE LA ACTUALIDAD ACUÍCOLA
# ⏱️  [------------------------------] 0.9% (17/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 10 - Tiempo: 27.05s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 10
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.05s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:23
# ⏳ Tiempo estimado restante: 12:07:50
# 🏁 Finalización estimada: 20:34:04
# 19 CODIGOMATERIA                 ACUG1056
# CLASIFMATERIA                        G
# MATERIA          PATOLOGÍA ACUÍCOLA II
# ANIO                              2020
# TERMINO                             0S
# DIFICULTAD                        7,85
# Name: 18, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 19/1892
# ============================================================
# 📚 Código: ACUG1056
# 📖 Nombre: PATOLOGÍA ACUÍCOLA II
# ⏱️  [------------------------------] 1.0% (18/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 5 - Tiempo: 26.41s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 5
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.41s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:23
# ⏳ Tiempo estimado restante: 12:12:32
# 🏁 Finalización estimada: 20:39:13
# 20 CODIGOMATERIA                ACUG1057
# CLASIFMATERIA                       G
# MATERIA          PATOLOGÍA ACUÍCOLA I
# ANIO                             2020
# TERMINO                            0S
# DIFICULTAD                       8,11
# Name: 19, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 20/1892
# ============================================================
# 📚 Código: ACUG1057
# 📖 Nombre: PATOLOGÍA ACUÍCOLA I
# ⏱️  [------------------------------] 1.0% (19/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.49s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 22 CODIGOMATERIA                           ACUG1059
# CLASIFMATERIA                                  G
# MATERIA          BUENAS PRÁCTICAS EN ACUICULTURA
# ANIO                                        2020
# TERMINO                                       0S
# DIFICULTAD                                  8,84
# Name: 21, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 22/1892
# ============================================================
# 📚 Código: ACUG1059
# 📖 Nombre: BUENAS PRÁCTICAS EN ACUICULTURA
# ⏱️  [------------------------------] 1.1% (21/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 9 - Tiempo: 26.73s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 9
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.73s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:23
# ⏳ Tiempo estimado restante: 12:16:27
# 🏁 Finalización estimada: 20:43:44
# 23 CODIGOMATERIA                       ADMG1005
# CLASIFMATERIA                              G
# MATERIA          EMPRENDIMIENTO E INNOVACIÓN
# ANIO                                    2020
# TERMINO                                   0S
# DIFICULTAD                              8,18
# Name: 22, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 23/1892
# ============================================================
# 📚 Código: ADMG1005
# 📖 Nombre: EMPRENDIMIENTO E INNOVACIÓN
# ⏱️  [------------------------------] 1.2% (22/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 969 - Tiempo: 57.10s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 969
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 57.10s
#    • Tiempo total materia: 0:00:57
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:05:42
# 🏁 Finalización estimada: 21:33:57
# 24 CODIGOMATERIA                                             ADMG1006
# CLASIFMATERIA                                                    G
# MATERIA          GESTIÓN DE PROYECTOS Y REGULACIÓN EN TELECOMUN...
# ANIO                                                          2020
# TERMINO                                                         0S
# DIFICULTAD                                                    7,92
# Name: 23, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 24/1892
# ============================================================
# 📚 Código: ADMG1006
# 📖 Nombre: GESTIÓN DE PROYECTOS Y REGULACIÓN EN TELECOMUNICACIONES
# ⏱️  [------------------------------] 1.2% (23/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 35 - Tiempo: 27.78s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 35
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.78s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:08:54
# 🏁 Finalización estimada: 21:37:37
# 25 CODIGOMATERIA                  ADMG1007
# CLASIFMATERIA                         G
# MATERIA          ESTRATEGIAS DE GESTIÓN
# ANIO                               2020
# TERMINO                              0S
# DIFICULTAD                         7,84
# Name: 24, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 25/1892
# ============================================================
# 📚 Código: ADMG1007
# 📖 Nombre: ESTRATEGIAS DE GESTIÓN
# ⏱️  [------------------------------] 1.3% (24/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.48s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 26 CODIGOMATERIA                       ADMG2001
# CLASIFMATERIA                              G
# MATERIA          EMPRENDIMIENTO E INNOVACIÓN
# ANIO                                    2017
# TERMINO                                   1S
# DIFICULTAD                              7,82
# Name: 25, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 26/1892
# ============================================================
# 📚 Código: ADMG2001
# 📖 Nombre: EMPRENDIMIENTO E INNOVACIÓN
# ⏱️  [------------------------------] 1.3% (25/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.90s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 27 CODIGOMATERIA                         ADMG2022
# CLASIFMATERIA                                G
# MATERIA          ADMINISTRACIÓN DE OPERACIONES
# ANIO                                      2020
# TERMINO                                     0S
# DIFICULTAD                                7,22
# Name: 26, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 27/1892
# ============================================================
# 📚 Código: ADMG2022
# 📖 Nombre: ADMINISTRACIÓN DE OPERACIONES
# ⏱️  [------------------------------] 1.4% (26/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 77 - Tiempo: 29.28s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 77
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 29.28s
#    • Tiempo total materia: 0:00:29
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:12:57
# 🏁 Finalización estimada: 21:42:31
# 28 CODIGOMATERIA             ADMG2024
# CLASIFMATERIA                    G
# MATERIA          COMERCIO EXTERIOR
# ANIO                          2020
# TERMINO                         0S
# DIFICULTAD                    7,63
# Name: 27, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 28/1892
# ============================================================
# 📚 Código: ADMG2024
# 📖 Nombre: COMERCIO EXTERIOR
# ⏱️  [------------------------------] 1.4% (27/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 35 - Tiempo: 27.53s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 35
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.53s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:15:09
# 🏁 Finalización estimada: 21:45:09
# 29 CODIGOMATERIA                         ADMG2025
# CLASIFMATERIA                                G
# MATERIA          COMPORTAMIENTO ORGANIZACIONAL
# ANIO                                      2020
# TERMINO                                     0S
# DIFICULTAD                                8,59
# Name: 28, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 29/1892
# ============================================================
# 📚 Código: ADMG2025
# 📖 Nombre: COMPORTAMIENTO ORGANIZACIONAL
# ⏱️  [------------------------------] 1.5% (28/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 108 - Tiempo: 28.38s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 108
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 28.38s
#    • Tiempo total materia: 0:00:28
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:18:11
# 🏁 Finalización estimada: 21:48:40
# 30 CODIGOMATERIA                     ADMG2026
# CLASIFMATERIA                            G
# MATERIA          DESARROLLO ORGANIZACIONAL
# ANIO                                  2020
# TERMINO                                 0S
# DIFICULTAD                            9,13
# Name: 29, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 30/1892
# ============================================================
# 📚 Código: ADMG2026
# 📖 Nombre: DESARROLLO ORGANIZACIONAL
# ⏱️  [------------------------------] 1.5% (29/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 54 - Tiempo: 27.67s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 54
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.67s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:20:05
# 🏁 Finalización estimada: 21:51:02
# 31 CODIGOMATERIA                                  ADMG2028
# CLASIFMATERIA                                         G
# MATERIA          ESTRATEGIAS CORPORATIVAS Y DE NEGOCIOS
# ANIO                                               2020
# TERMINO                                              0S
# DIFICULTAD                                         7,66
# Name: 30, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 31/1892
# ============================================================
# 📚 Código: ADMG2028
# 📖 Nombre: ESTRATEGIAS CORPORATIVAS Y DE NEGOCIOS
# ⏱️  [------------------------------] 1.6% (30/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 40 - Tiempo: 27.06s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 40
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.06s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:21:08
# 🏁 Finalización estimada: 21:52:32
# 32 CODIGOMATERIA                         ADMG2029
# CLASIFMATERIA                                G
# MATERIA          FUNDAMENTOS DE ADMINISTRACIÓN
# ANIO                                      2020
# TERMINO                                     0S
# DIFICULTAD                                8,12
# Name: 31, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 32/1892
# ============================================================
# 📚 Código: ADMG2029
# 📖 Nombre: FUNDAMENTOS DE ADMINISTRACIÓN
# ⏱️  [------------------------------] 1.6% (31/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 188 - Tiempo: 28.47s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 188
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 28.47s
#    • Tiempo total materia: 0:00:28
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:23:37
# 🏁 Finalización estimada: 21:55:30
# 33 CODIGOMATERIA                    ADMG2030
# CLASIFMATERIA                           G
# MATERIA          FUNDAMENTOS DE MARKETING
# ANIO                                 2020
# TERMINO                                0S
# DIFICULTAD                           8,37
# Name: 32, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 33/1892
# ============================================================
# 📚 Código: ADMG2030
# 📖 Nombre: FUNDAMENTOS DE MARKETING
# ⏱️  [------------------------------] 1.7% (32/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 90 - Tiempo: 26.38s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 90
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.38s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:23:41
# 🏁 Finalización estimada: 21:56:00
# 35 CODIGOMATERIA             ADMG2032
# CLASIFMATERIA                    G
# MATERIA          GESTIÓN COMERCIAL
# ANIO                          2020
# TERMINO                         0S
# DIFICULTAD                    8,44
# Name: 34, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 35/1892
# ============================================================
# 📚 Código: ADMG2032
# 📖 Nombre: GESTIÓN COMERCIAL
# ⏱️  [------------------------------] 1.8% (34/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 69 - Tiempo: 27.06s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 69
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.06s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:25
# ⏳ Tiempo estimado restante: 13:23:58
# 🏁 Finalización estimada: 21:56:44
# 36 CODIGOMATERIA                ADMG2033
# CLASIFMATERIA                       G
# MATERIA          GESTIÓN DE MARKETING
# ANIO                             2020
# TERMINO                            0S
# DIFICULTAD                       8,69
# Name: 35, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 36/1892
# ============================================================
# 📚 Código: ADMG2033
# 📖 Nombre: GESTIÓN DE MARKETING
# ⏱️  [------------------------------] 1.8% (35/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 42 - Tiempo: 27.21s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 42
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.21s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:24:46
# 🏁 Finalización estimada: 21:57:59
# 37 CODIGOMATERIA                       ADMG2034
# CLASIFMATERIA                              G
# MATERIA          GESTIÓN DE RECURSOS HUMANOS
# ANIO                                    2020
# TERMINO                                   0S
# DIFICULTAD                              8,50
# Name: 36, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 37/1892
# ============================================================
# 📚 Código: ADMG2034
# 📖 Nombre: GESTIÓN DE RECURSOS HUMANOS
# ⏱️  [------------------------------] 1.9% (36/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 39 - Tiempo: 28.40s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 39
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 28.40s
#    • Tiempo total materia: 0:00:28
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:26:38
# 🏁 Finalización estimada: 22:00:20
# 38 CODIGOMATERIA                     ADMG2035
# CLASIFMATERIA                            G
# MATERIA          INVESTIGACIÓN DE MERCADOS
# ANIO                                  2020
# TERMINO                                 0S
# DIFICULTAD                            7,32
# Name: 37, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 38/1892
# ============================================================
# 📚 Código: ADMG2035
# 📖 Nombre: INVESTIGACIÓN DE MERCADOS
# ⏱️  [------------------------------] 2.0% (37/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 152 - Tiempo: 29.20s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 152
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 29.20s
#    • Tiempo total materia: 0:00:29
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:29:07
# 🏁 Finalización estimada: 22:03:18
# 39 CODIGOMATERIA                     ADMG2036
# CLASIFMATERIA                            G
# MATERIA          PLANIFICACIÓN ESTRATÉGICA
# ANIO                                  2020
# TERMINO                                 0S
# DIFICULTAD                            8,37
# Name: 38, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 39/1892
# ============================================================
# 📚 Código: ADMG2036
# 📖 Nombre: PLANIFICACIÓN ESTRATÉGICA
# ⏱️  [------------------------------] 2.0% (38/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 48 - Tiempo: 26.78s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 48
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.78s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:29:13
# 🏁 Finalización estimada: 22:03:51
# 40 CODIGOMATERIA                ADMG2037
# CLASIFMATERIA                       G
# MATERIA          GESTIÓN DE PROYECTOS
# ANIO                             2020
# TERMINO                            0S
# DIFICULTAD                       8,65
# Name: 39, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 40/1892
# ============================================================
# 📚 Código: ADMG2037
# 📖 Nombre: GESTIÓN DE PROYECTOS
# ⏱️  [------------------------------] 2.1% (39/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 53 - Tiempo: 27.02s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 53
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.02s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:29:30
# 🏁 Finalización estimada: 22:04:35
# 41 CODIGOMATERIA                      ADMT3004
# CLASIFMATERIA                             G
# MATERIA          LIDERAZGO Y EMPRENDIMIENTO
# ANIO                                   2024
# TERMINO                                  0S
# DIFICULTAD                             8,67
# Name: 40, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 41/1892
# ============================================================
# 📚 Código: ADMT3004
# 📖 Nombre: LIDERAZGO Y EMPRENDIMIENTO
# ⏱️  [------------------------------] 2.1% (40/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.58s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 42 CODIGOMATERIA             ADMT3005
# CLASIFMATERIA                    G
# MATERIA          COMERCIO EXTERIOR
# ANIO                          2024
# TERMINO                         0S
# DIFICULTAD                    7,89
# Name: 41, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 42/1892
# ============================================================
# 📚 Código: ADMT3005
# 📖 Nombre: COMERCIO EXTERIOR
# ⏱️  [------------------------------] 2.2% (41/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.97s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 43 CODIGOMATERIA                               ADSG1001
# CLASIFMATERIA                                      G
# MATERIA          INTRODUCCIÓN A LA GESTIÓN AMBIENTAL
# ANIO                                            2016
# TERMINO                                           1S
# DIFICULTAD                                      7,65
# Name: 42, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 43/1892
# ============================================================
# 📚 Código: ADSG1001
# 📖 Nombre: INTRODUCCIÓN A LA GESTIÓN AMBIENTAL
# ⏱️  [------------------------------] 2.2% (42/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.99s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 44 CODIGOMATERIA                   ADSG1019
# CLASIFMATERIA                          G
# MATERIA          CONTAMINACIÓN AMBIENTAL
# ANIO                                2020
# TERMINO                               0S
# DIFICULTAD                          8,52
# Name: 43, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 44/1892
# ============================================================
# 📚 Código: ADSG1019
# 📖 Nombre: CONTAMINACIÓN AMBIENTAL
# ⏱️  [------------------------------] 2.3% (43/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 19 - Tiempo: 26.44s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 19
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.44s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:27:57
# 🏁 Finalización estimada: 22:04:00
# 45 CODIGOMATERIA             ADSG1020
# CLASIFMATERIA                    G
# MATERIA          ECOLOGÍA ACUÁTICA
# ANIO                          2020
# TERMINO                         0S
# DIFICULTAD                    8,40
# Name: 44, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 45/1892
# ============================================================
# 📚 Código: ADSG1020
# 📖 Nombre: ECOLOGÍA ACUÁTICA
# ⏱️  [------------------------------] 2.3% (44/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 21 - Tiempo: 26.58s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 21
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.58s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:27:48
# 🏁 Finalización estimada: 22:04:18
# 46 CODIGOMATERIA                   ADSG1021
# CLASIFMATERIA                          G
# MATERIA          ECOLOGÍA DE ECOSISTEMAS
# ANIO                                2020
# TERMINO                               0S
# DIFICULTAD                          8,72
# Name: 45, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 46/1892
# ============================================================
# 📚 Código: ADSG1021
# 📖 Nombre: ECOLOGÍA DE ECOSISTEMAS
# ⏱️  [------------------------------] 2.4% (45/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 15 - Tiempo: 26.76s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 15
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.76s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:27:47
# 🏁 Finalización estimada: 22:04:44
# 47 CODIGOMATERIA            ADSG1022
# CLASIFMATERIA                   G
# MATERIA          ECOLOGÍA GENERAL
# ANIO                         2020
# TERMINO                        0S
# DIFICULTAD                   8,22
# Name: 46, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 47/1892
# ============================================================
# 📚 Código: ADSG1022
# 📖 Nombre: ECOLOGÍA GENERAL
# ⏱️  [------------------------------] 2.4% (46/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 19 - Tiempo: 27.12s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 19
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.12s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:28:02
# 🏁 Finalización estimada: 22:05:26
# 48 CODIGOMATERIA                 ADSG1023
# CLASIFMATERIA                        G
# MATERIA          REMEDIACIÓN AMBIENTAL
# ANIO                              2021
# TERMINO                             0S
# DIFICULTAD                        9,55
# Name: 47, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 48/1892
# ============================================================
# 📚 Código: ADSG1023
# 📖 Nombre: REMEDIACIÓN AMBIENTAL
# ⏱️  [------------------------------] 2.5% (47/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 8 - Tiempo: 26.81s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 8
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.81s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:28:00
# 🏁 Finalización estimada: 22:05:51
# 49 CODIGOMATERIA                        ADSG1024
# CLASIFMATERIA                               G
# MATERIA          PRINCIPIOS DE ECOTOXICOLOGÍA
# ANIO                                     2020
# TERMINO                                    0S
# DIFICULTAD                               8,30
# Name: 48, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 49/1892
# ============================================================
# 📚 Código: ADSG1024
# 📖 Nombre: PRINCIPIOS DE ECOTOXICOLOGÍA
# ⏱️  [------------------------------] 2.5% (48/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 30 - Tiempo: 26.25s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 30
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.25s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:27:32
# 🏁 Finalización estimada: 22:05:49
# 50 CODIGOMATERIA                                             ADSG1025
# CLASIFMATERIA                                                    G
# MATERIA          GESTIÓN DE CALIDAD, AMBIENTE Y SEGURIDAD EN LA...
# ANIO                                                          2020
# TERMINO                                                         0S
# DIFICULTAD                                                    7,99
# Name: 49, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 50/1892
# ============================================================
# 📚 Código: ADSG1025
# 📖 Nombre: GESTIÓN DE CALIDAD, AMBIENTE Y SEGURIDAD EN LA INDUSTRIA
# ⏱️  [------------------------------] 2.6% (49/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 18 - Tiempo: 26.27s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 18
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.27s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:27:05
# 🏁 Finalización estimada: 22:05:48
# 51 CODIGOMATERIA                         ADSG1026
# CLASIFMATERIA                                G
# MATERIA          CIENCIAS DE LA SOSTENIBILIDAD
# ANIO                                      2020
# TERMINO                                     0S
# DIFICULTAD                                8,10
# Name: 50, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 51/1892
# ============================================================
# 📚 Código: ADSG1026
# 📖 Nombre: CIENCIAS DE LA SOSTENIBILIDAD
# ⏱️  [------------------------------] 2.6% (50/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 549 - Tiempo: 33.48s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 549
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 33.48s
#    • Tiempo total materia: 0:00:33
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:31:47
# 🏁 Finalización estimada: 22:11:04
# 52 CODIGOMATERIA                ADSG1029
# CLASIFMATERIA                       G
# MATERIA          TRATAMIENTO DE AGUAS
# ANIO                             2020
# TERMINO                            0S
# DIFICULTAD                       7,87
# Name: 51, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 52/1892
# ============================================================
# 📚 Código: ADSG1029
# 📖 Nombre: TRATAMIENTO DE AGUAS
# ⏱️  [------------------------------] 2.7% (51/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 34 - Tiempo: 26.77s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 34
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.77s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:31:33
# 🏁 Finalización estimada: 22:11:17
# 53 CODIGOMATERIA                ADST3002
# CLASIFMATERIA                       G
# MATERIA          CIENCIAS AMBIENTALES
# ANIO                             2024
# TERMINO                            0S
# DIFICULTAD                       8,64
# Name: 52, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 53/1892
# ============================================================
# 📚 Código: ADST3002
# 📖 Nombre: CIENCIAS AMBIENTALES
# ⏱️  [------------------------------] 2.7% (52/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.43s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 54 CODIGOMATERIA                    AGRG1022
# CLASIFMATERIA                           G
# MATERIA          AGRICULTURA DE PRECISIÓN
# ANIO                                 2020
# TERMINO                                0S
# DIFICULTAD                           7,00
# Name: 53, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 54/1892
# ============================================================
# 📚 Código: AGRG1022
# 📖 Nombre: AGRICULTURA DE PRECISIÓN
# ⏱️  [------------------------------] 2.8% (53/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.15s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 55 CODIGOMATERIA           AGRG1023
# CLASIFMATERIA                  G
# MATERIA          AGROECOSISTEMAS
# ANIO                        2020
# TERMINO                       0S
# DIFICULTAD                  8,22
# Name: 54, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 55/1892
# ============================================================
# 📚 Código: AGRG1023
# 📖 Nombre: AGROECOSISTEMAS
# ⏱️  [------------------------------] 2.9% (54/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 6 - Tiempo: 26.36s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 6
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 26.36s
#    • Tiempo total materia: 0:00:26
# ⏰ Tiempo promedio por materia: 0:00:26
# ⏳ Tiempo estimado restante: 13:30:09
# 🏁 Finalización estimada: 22:10:40
# 56 CODIGOMATERIA                               AGRG1024
# CLASIFMATERIA                                      G
# MATERIA          DIAGNÓSTICO Y PROTECCIÓN VEGETAL II
# ANIO                                            2020
# TERMINO                                           0S
# DIFICULTAD                                      8,34
# Name: 55, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 56/1892
# ============================================================
# 📚 Código: AGRG1024
# 📖 Nombre: DIAGNÓSTICO Y PROTECCIÓN VEGETAL II
# ⏱️  [------------------------------] 2.9% (55/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 0 - Tiempo: 10.55s
# ⚠️  No hay estudiantes para esta materia, saltando...
# 57 CODIGOMATERIA                              AGRG1025
# CLASIFMATERIA                                     G
# MATERIA          DIAGNÓSTICO Y PROTECCIÓN VEGETAL I
# ANIO                                           2020
# TERMINO                                          0S
# DIFICULTAD                                     8,04
# Name: 56, dtype: object
#
# ============================================================
# ...
# CLASIFMATERIA                                      G
# MATERIA          TELEMÁTICA Y TRANSFORMACIÓN DIGITAL
# ANIO                                            2020
# TERMINO                                           0S
# DIFICULTAD                                      7,61
# Name: 1908, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1909/1892
# ============================================================
# 📚 Código: TLMG1036
# 📖 Nombre: TELEMÁTICA Y TRANSFORMACIÓN DIGITAL
# ⏱️  [██████████████████████████████] 100.8% (1908/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 14 - Tiempo: 27.06s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 14
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 27.06s
#    • Tiempo total materia: 0:00:27
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:51:04
# 🏁 Finalización estimada: 17:47:27
# 1910 CODIGOMATERIA                                TLMG1037
# CLASIFMATERIA                                       G
# MATERIA          PROGRAMACIÓN DE SISTEMAS TELEMÁTICOS
# ANIO                                             2020
# TERMINO                                            0S
# DIFICULTAD                                       8,16
# Name: 1909, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1910/1892
# ============================================================
# 📚 Código: TLMG1037
# 📖 Nombre: PROGRAMACIÓN DE SISTEMAS TELEMÁTICOS
# ⏱️  [██████████████████████████████] 100.9% (1909/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 55 - Tiempo: 24.03s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 55
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 24.03s
#    • Tiempo total materia: 0:00:24
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:50:32
# 🏁 Finalización estimada: 17:47:19
# 1911 CODIGOMATERIA             TURG2018
# CLASIFMATERIA                    G
# MATERIA          AGENCIAS DE VIAJE
# ANIO                          2020
# TERMINO                         0S
# DIFICULTAD                    7,62
# Name: 1910, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1911/1892
# ============================================================
# 📚 Código: TURG2018
# 📖 Nombre: AGENCIAS DE VIAJE
# ⏱️  [██████████████████████████████] 101.0% (1910/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 32 - Tiempo: 23.71s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 32
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 23.71s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:50:01
# 🏁 Finalización estimada: 17:47:12
# 1912 CODIGOMATERIA               TURG2019
# CLASIFMATERIA                      G
# MATERIA          ALIMENTOS Y BEBIDAS
# ANIO                            2020
# TERMINO                           0S
# DIFICULTAD                      7,44
# Name: 1911, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1912/1892
# ============================================================
# 📚 Código: TURG2019
# 📖 Nombre: ALIMENTOS Y BEBIDAS
# ⏱️  [██████████████████████████████] 101.0% (1911/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 66 - Tiempo: 23.29s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 66
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 23.29s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:49:30
# 🏁 Finalización estimada: 17:47:04
# 1913 CODIGOMATERIA               TURG2020
# CLASIFMATERIA                      G
# MATERIA          CONGRESOS Y EVENTOS
# ANIO                            2021
# TERMINO                           0S
# DIFICULTAD                      9,01
# Name: 1912, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1913/1892
# ============================================================
# 📚 Código: TURG2020
# 📖 Nombre: CONGRESOS Y EVENTOS
# ⏱️  [██████████████████████████████] 101.1% (1912/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 17 - Tiempo: 21.85s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 17
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 21.85s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:48:59
# 🏁 Finalización estimada: 17:46:55
# 1914 CODIGOMATERIA                                      TURG2021
# CLASIFMATERIA                                             G
# MATERIA          CONSERVACIÓN Y MANEJO AMBIENTAL EN TURISMO
# ANIO                                                   2020
# TERMINO                                                  0S
# DIFICULTAD                                             8,54
# Name: 1913, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1914/1892
# ============================================================
# 📚 Código: TURG2021
# 📖 Nombre: CONSERVACIÓN Y MANEJO AMBIENTAL EN TURISMO
# ⏱️  [██████████████████████████████] 101.1% (1913/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 22 - Tiempo: 22.00s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 22
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 22.00s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:48:28
# 🏁 Finalización estimada: 17:46:45
# 1915 CODIGOMATERIA                         TURG2022
# CLASIFMATERIA                                G
# MATERIA          DERECHO TURÍSTICO Y AMBIENTAL
# ANIO                                      2020
# TERMINO                                     0S
# DIFICULTAD                                7,54
# Name: 1914, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1915/1892
# ============================================================
# 📚 Código: TURG2022
# 📖 Nombre: DERECHO TURÍSTICO Y AMBIENTAL
# ⏱️  [██████████████████████████████] 101.2% (1914/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 33 - Tiempo: 23.40s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 33
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 23.40s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:47:56
# 🏁 Finalización estimada: 17:46:38
# 1916 CODIGOMATERIA                             TURG2023
# CLASIFMATERIA                                    G
# MATERIA          DESARROLLO SOSTENIBLE DEL TURISMO
# ANIO                                          2020
# TERMINO                                         0S
# DIFICULTAD                                    8,65
# Name: 1915, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1916/1892
# ============================================================
# 📚 Código: TURG2023
# 📖 Nombre: DESARROLLO SOSTENIBLE DEL TURISMO
# ⏱️  [██████████████████████████████] 101.2% (1915/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 6 - Tiempo: 21.58s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 6
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 21.58s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:47:25
# 🏁 Finalización estimada: 17:46:28
# 1917 CODIGOMATERIA                                  TURG2024
# CLASIFMATERIA                                         G
# MATERIA          FUNDAMENTOS DE PLANIFICACIÓN TURÍSTICA
# ANIO                                               2020
# TERMINO                                              0S
# DIFICULTAD                                         6,05
# Name: 1916, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1917/1892
# ============================================================
# 📚 Código: TURG2024
# 📖 Nombre: FUNDAMENTOS DE PLANIFICACIÓN TURÍSTICA
# ⏱️  [██████████████████████████████] 101.3% (1916/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 62 - Tiempo: 22.64s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 62
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 22.64s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:46:54
# 🏁 Finalización estimada: 17:46:20
# 1919 CODIGOMATERIA            TURG2030
# CLASIFMATERIA                   G
# MATERIA          GESTIÓN HOTELERA
# ANIO                         2020
# TERMINO                        0S
# DIFICULTAD                   7,96
# Name: 1918, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1919/1892
# ============================================================
# 📚 Código: TURG2030
# 📖 Nombre: GESTIÓN HOTELERA
# ⏱️  [██████████████████████████████] 101.4% (1918/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 39 - Tiempo: 22.68s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 39
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 22.68s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:45:52
# 🏁 Finalización estimada: 17:45:40
# 1920 CODIGOMATERIA               TURG2031
# CLASIFMATERIA                      G
# MATERIA          MARKETING TURÍSTICO
# ANIO                            2020
# TERMINO                           0S
# DIFICULTAD                      7,47
# Name: 1919, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1920/1892
# ============================================================
# 📚 Código: TURG2031
# 📖 Nombre: MARKETING TURÍSTICO
# ⏱️  [██████████████████████████████] 101.4% (1919/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 41 - Tiempo: 22.73s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 41
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 22.73s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:45:21
# 🏁 Finalización estimada: 17:45:32
# 1921 CODIGOMATERIA                               TURG2032
# CLASIFMATERIA                                      G
# MATERIA          MÉTODOS DE INVESTIGACIÓN EN TURISMO
# ANIO                                            2020
# TERMINO                                           0S
# DIFICULTAD                                      7,76
# Name: 1920, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1921/1892
# ============================================================
# 📚 Código: TURG2032
# 📖 Nombre: MÉTODOS DE INVESTIGACIÓN EN TURISMO
# ⏱️  [██████████████████████████████] 101.5% (1920/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 29 - Tiempo: 23.69s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 29
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 23.69s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:44:50
# 🏁 Finalización estimada: 17:45:24
# 1922 CODIGOMATERIA                                TURG2033
# CLASIFMATERIA                                       G
# MATERIA          PLANIFICACIÓN DE ESPACIOS TURÍSTICOS
# ANIO                                             2020
# TERMINO                                            0S
# DIFICULTAD                                       7,47
# Name: 1921, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1922/1892
# ============================================================
# 📚 Código: TURG2033
# 📖 Nombre: PLANIFICACIÓN DE ESPACIOS TURÍSTICOS
# ⏱️  [██████████████████████████████] 101.5% (1921/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 17 - Tiempo: 22.51s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 17
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 22.51s
#    • Tiempo total materia: 0:00:22
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:44:19
# 🏁 Finalización estimada: 17:45:16
# 1923 CODIGOMATERIA                         TURG2034
# CLASIFMATERIA                                G
# MATERIA          PATRIMONIO NATURAL Y CULTURAL
# ANIO                                      2020
# TERMINO                                     0S
# DIFICULTAD                                8,09
# Name: 1922, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1923/1892
# ============================================================
# 📚 Código: TURG2034
# 📖 Nombre: PATRIMONIO NATURAL Y CULTURAL
# ⏱️  [██████████████████████████████] 101.6% (1922/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 37 - Tiempo: 21.95s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 37
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 21.95s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:43:48
# 🏁 Finalización estimada: 17:45:07
# 1924 CODIGOMATERIA               TURG2035
# CLASIFMATERIA                      G
# MATERIA          GEOGRAFÍA TURÍSTICA
# ANIO                            2020
# TERMINO                           0S
# DIFICULTAD                      6,48
# Name: 1923, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1924/1892
# ============================================================
# 📚 Código: TURG2035
# 📖 Nombre: GEOGRAFÍA TURÍSTICA
# ⏱️  [██████████████████████████████] 101.6% (1923/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 39 - Tiempo: 23.13s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 39
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 23.13s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:43:17
# 🏁 Finalización estimada: 17:44:59
# 1925 CODIGOMATERIA              TURG2036
# CLASIFMATERIA                     G
# MATERIA          TEORÍA DEL TURISMO
# ANIO                           2020
# TERMINO                          0S
# DIFICULTAD                     7,51
# Name: 1924, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1925/1892
# ============================================================
# 📚 Código: TURG2036
# 📖 Nombre: TEORÍA DEL TURISMO
# ⏱️  [██████████████████████████████] 101.7% (1924/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 32 - Tiempo: 21.12s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 32
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 21.12s
#    • Tiempo total materia: 0:00:21
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:42:46
# 🏁 Finalización estimada: 17:44:49
# 1926 CODIGOMATERIA               TURG2037
# CLASIFMATERIA                      G
# MATERIA          OPERACIÓN TURÍSTICA
# ANIO                            2020
# TERMINO                           0S
# DIFICULTAD                      7,91
# Name: 1925, dtype: object
#
# ============================================================
# PROCESANDO MATERIA 1926/1892
# ============================================================
# 📚 Código: TURG2037
# 📖 Nombre: OPERACIÓN TURÍSTICA
# ⏱️  [██████████████████████████████] 101.7% (1925/1892)
#
# 🔍 Ejecutando query de historial académico...
# ✅ Query 1 completada - Estudiantes encontrados: 39 - Tiempo: 23.00s
#
# 📈 RESUMEN MATERIA:
#    • Estudiantes académicos: 39
#    • Cobertura socioeconómica: 100.0%
#    • Query 1: 23.00s
#    • Tiempo total materia: 0:00:23
# ⏰ Tiempo promedio por materia: 0:00:31
# ⏳ Tiempo estimado restante: -1 day, 23:42:15
# 🏁 Finalización estimada: 17:44:41

# %%
df_complete.shape
# Out:
# (31286, 27)

# %%
filename = f"./data/materias/all_{year}_{semester}.csv"
df_complete.to_csv(filename, index=False)
print(f"✅ Archivo guardado: {filename}")
# Out:
# ✅ Archivo guardado: ./data/materias/all_2021_2S.csv

# %%
# Cerrar conexión
print(f"\n🔌 Cerrando conexión a la base de datos...")
ibm_db.close(conn)

# Tiempo total
end_time_total = time.time()
total_time = end_time_total - start_time_total
# Out:
# 🔌 Cerrando conexión a la base de datos...

# %%
print("\n" + "="*80)
print("RESUMEN FINAL DEL PROCESAMIENTO")
print("="*80)
print(f"🏁 Fecha y hora de finalización: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"⏱️  Tiempo total de ejecución: {format_time(total_time)}")
print(f"📊 Materias procesadas exitosamente: {total_materias - len(failed_materias)}/{total_materias}")
print(f"👥 Total estudiantes procesados: {total_students_processed:,}")
# Out:
# ================================================================================
# RESUMEN FINAL DEL PROCESAMIENTO
# ================================================================================
# 🏁 Fecha y hora de finalización: 2025-10-08 18:02:27
# ⏱️  Tiempo total de ejecución: 9:43:46
# 📊 Materias procesadas exitosamente: 1892/1892
# 👥 Total estudiantes procesados: 31,286

# %%
if processing_times:
    avg_time = sum(processing_times) / len(processing_times)
    min_time = min(processing_times)
    max_time = max(processing_times)
    
    print(f"\n📈 ESTADÍSTICAS DE TIEMPO:")
    print(f"   • Tiempo promedio por materia: {format_time(avg_time)}")
    print(f"   • Tiempo mínimo: {format_time(min_time)}")
    print(f"   • Tiempo máximo: {format_time(max_time)}")
    print(f"   • Velocidad promedio: {total_students_processed/total_time:.1f} estudiantes/segundo")
# Out:
# 📈 ESTADÍSTICAS DE TIEMPO:
#    • Tiempo promedio por materia: 0:00:31
#    • Tiempo mínimo: 0:00:18
#    • Tiempo máximo: 0:00:57
#    • Velocidad promedio: 0.9 estudiantes/segundo

# %%
if failed_materias:
    print(f"\n❌ MATERIAS CON ERRORES ({len(failed_materias)}):")
    for failed in failed_materias:
        print(f"   • {failed['codigo']} - {failed['nombre'][:50]}")
        print(f"     Error: {failed['error']}")

# %% [markdown]
# ❌ MATERIAS CON ERRORES (15):
#    • ACUG1045 - PRODUCCIÓN ACUÍCOLA II
#      Error: 'CODESTUDIANTE'
#    • ALIG1033 - DISEÑO DE PLANTAS ALIMENTARIAS
#      Error: 'CODESTUDIANTE'
#    • CCPG1058 - SISTEMAS DE INFORMACIÓN APLICADOS A LOGÍSTICA
#      Error: 'CODESTUDIANTE'
#    • ESTG1056 - DATOS NO ESTRUCTURADOS
#      Error: 'CODESTUDIANTE'
#    • GEOG1027 - DISEÑO DE CAMPO GEOLÓGICO
#      Error: 'CODESTUDIANTE'
#    • GEOG1037 - INGENIERÍA GEOLÓGICA
#      Error: 'CODESTUDIANTE'
#    • INDG1061 - HSEQ EN LA INDUSTRIA HIDROCARBURÍFERA
#      Error: 'CODESTUDIANTE'
#    • MING1031 - PLANEAMIENTO Y DISEÑO MINERO
#      Error: 'CODESTUDIANTE'
#    • MTRG1027 - DISEÑO DE MATERIALES COMPUESTOS
#      Error: 'CODESTUDIANTE'
#    • MTRG1041 - NANOTECNOLOGÍA Y NANOMATERIALES
#      Error: 'CODESTUDIANTE'
#    • PETG1022 - INGENIERÍA DE PRODUCCIÓN II
#      Error: 'CODESTUDIANTE'
#    • PETG1023 - INGENIERÍA DE YACIMIENTOS I
#      Error: 'CODESTUDIANTE'
#    • PETG1024 - INGENIERÍA DE YACIMIENTOS II
#      Error: 'CODESTUDIANTE'
#    • PETG1028 - SIMULACIÓN DE RESERVORIOS
#      Error: 'CODESTUDIANTE'
#    • PETG1034 - EVALUACIÓN DE FORMACIONES II
#      Error: 'CODESTUDIANTE'

# %%
print(f"\n✅ Procesamiento completado!")
print("="*80)
# Out:
# ✅ Procesamiento completado!
# ================================================================================
